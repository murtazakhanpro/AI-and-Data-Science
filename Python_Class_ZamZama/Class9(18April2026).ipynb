# %% [markdown]
# # Dictionary

# %%
student_list = [12, 23, 5.6, 'Python', 'KARACHI']

# %%
student_dict = {'roll':12,'age':23, 'height':5.6, 'city':'Karachi'}

# %%
len(student_dict)
# Out:
# 4

# %% [markdown]
# # Description

# %% [raw]
# Python Dictionary is formed using {}
# Dictionary contains items>>> key:value
# Dictionary mutable
# Dictionary can be accessed using key

# %%
student_dict
# Out:
# {'roll': 12, 'age': 23, 'height': 5.6, 'city': 'Karachi'}

# %%
student_dict['city']
# Out:
# 'Karachi'

# %%
student_dict['roll']
# Out:
# 12

# %%
student_dict['NAME']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9060\2362658217.py in <module>
# ----> 1 student_dict['NAME']
#
# KeyError: 'NAME'

# %% [markdown]
# # Adding more items to an existing dictionary

# %%
student_dict['contact'] ='03323446734'

# %%
student_dict
# Out:
# {'roll': 12,
#  'age': 23,
#  'height': 5.6,
#  'city': 'Karachi',
#  'contact': '03323446734'}

# %% [markdown]
# # Delete an item from Dictionary
#     - del
#     - pop()
#     - popitem()

# %%
del student_dict['height']

# %%
student_dict
# Out:
# {'roll': 12, 'age': 23, 'city': 'Karachi', 'contact': '03323446734'}

# %%
student_dict.pop('roll')
# Out:
# 12

# %%
student_dict.popitem()  # sub se last wala item delete kardega.
# Out:
# ('contact', '03323446734')

# %% [markdown]
# # Update:

# %%
student_dict
# Out:
# {'age': 23, 'city': 'Karachi'}

# %%
student_dict['city'] = 'Hyderabad'

# %%
student_dict
# Out:
# {'age': 23, 'city': 'Hyderabad'}

# %%
student_dict.get('age') , student_dict['age']
# Out:
# (23, 23)

# %%
student_dict['Age']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9060\4197595390.py in <module>
# ----> 1 student_dict['Age']
#
# KeyError: 'Age'

# %%
student_dict.get('Age')

# %%
student_dict.get('Age',"Key Not found")
# Out:
# 'Key Not found'

# %%
student_dict.get('city',"Key Not found")
# Out:
# 'Hyderabad'
