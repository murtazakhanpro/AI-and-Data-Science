# %% [markdown]
# # Introduction to programming in Python

# %% [markdown]
# ## Introduction to programming in Python

# %% [markdown]
# ### Introduction to programming in Python

# %% [markdown]
# #### Introduction to programming in Python

# %% [markdown]
# ##### Introduction to programming in Python

# %% [markdown]
# ###### Introduction to programming in Python

# %%
print("Hello Python")
# Out:
# Hello Python

# %%
print("Programming")
# Out:
# Programming

# %% [markdown]
# # print()
# - print is python function/command to print any valid value on the console.
#
# - print can take no value, 1 value or many value altogether comma separated.

# %%
print()

# %%
print(100)
# Out:
# 100

# %%
print("Hello", 200)
# Out:
# Hello 200

# %%
print("Python","Anconda",100,200)
# Out:
# Python Anconda 100 200

# %% [markdown]
# # Valid Values:
#    - Values  >>>>>> Data
#    - Data Type:
#           Text
#           Numbers

# %% [markdown]
# # Data Types
#    - Text Data (String) in Python >>>>>> str >>>
#
#      Everything under quoatations is treated as string.
#
#      Quatations: single , double , tripple single , tripple double

# %%
print('I am a single quoated String')
# Out:
# I am a single quoated String

# %%
print("I am a double quoated String")
# Out:
# I am a double quoated String

# %%
print('''I am a tripple single quoated String''')
# Out:
# I am a tripple single quoated String

# %%
print("""I am a tripple double quoated String""")
# Out:
# I am a tripple double quoated String

# %%
print('I am line2
      I am line2')
# Out:
#   File "C:\Users\SMIT\AppData\Local\Temp\ipykernel_3040\4176197722.py", line 1
#     print('I am line2
#                      ^
# SyntaxError: EOL while scanning string literal

# %%
print("I am line2
      I am line2")
# Out:
#   File "C:\Users\SMIT\AppData\Local\Temp\ipykernel_3040\1541062845.py", line 1
#     print("I am line2
#                      ^
# SyntaxError: EOL while scanning string literal

# %%
print("""I am line2
      I am line2""")
# Out:
# I am line2
#       I am line2
