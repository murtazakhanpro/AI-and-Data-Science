# %% [markdown]
# # 🔹 Q1 Aik variable a banao jisme value 20 ho, aur aik variable b banao jisme value 5 ho. In dono ko divide karo aur result print karo.

# %%
# type your code here

# %%
num1 = 20
num2 = 5
result = num1 / num2
print(result)
# Out:
# 4.0

# %%
print(num1/num2)
# Out:
# 4.0

# %% [markdown]
# # 🔹 Q2 Aik variable name banao jisme apna naam likho. Usay print karo aur uska lower case bhi print karo.

# %%
# type your code here

# %%
name = "Murtaza Ali"
print(name.lower())
# Out:
# murtaza ali

# %%
name.upper()
# Out:
# 'MURTAZA ALI'

# %% [markdown]
# # 🔹 Q3 Aik string likho: "hello world from python" Isay aise print karo ke har word ka pehla letter capital ho.

# %%
# type your code here

# %%
my_string = "hello world from python"
my_string_cap = my_string.title()

# %%
print(my_string_cap)
# Out:
# Hello World From Python

# %% [markdown]
# # 🔹 Q4 Aik variable x = 10 aur y = 3 banao. Inka modulus (%) nikaal kar print karo.

# %%
# type your code here

# %%
x  = 10
y = 3
result = (x % y)

# %%
print(result)
# Out:
# 1

# %% [markdown]
# # 🔹 Q5 Aik variable text = "PYTHON" banao. Isay lower case mai convert karke print karo

# %%
# type your code here

# %%
var_text = "PYTHON"

# %%
print(var_text.lower())
# Out:
# python

# %% [markdown]
# # 🔹 Q6 Aik string "data science" likho. Iski length nikaal kar print karo

# %%
# type your code here

# %%
char1 = "data science"

# %%
print(len(char1))
# Out:
# 12

# %% [markdown]
# # 🔹 Q7 Aik variable num = 7 banao. Iska square (power) nikaal kar print karo.

# %%
# type your code here

# %%
num7 = 7
power = 3
result = num7 ** power

# %%
print(result)
# Out:
# 343

# %% [markdown]
# # 🔹 Q8 Aik string "hello" likho. Isay 3 dafa repeat karke print karo.

# %%
# type your code here

# %%
linkho = "hello"
likho_1 = linkho * 3

# %%
print(likho_1)
# Out:
# hellohellohello

# %% [markdown]
# # 🔹 Q9 Aik variable a = 15 aur b = 10 banao. Check karo ke a bara hai b se ya nahi aur result print karo

# %%
# type your code here

# %%
a = 15
b = 10
if a > b:
    print("a is bigger that b")
else:
    print("a is lower than b")
# Out:
# a is bigger that b

# %% [markdown]
# # 🔹 Q10 Aik string "i love python programming" likho. Isay aise print karo ke pehla letter capital ho (sirf first letter).

# %%
# type your code here

# %%
var1 = "i love python programming"

# %%
print(var1.capitalize())
# Out:
# I love python programming

# %% [markdown]
# # 🔹 Q11 (Addition Input) User se 2 numbers lo aur unka sum print karo using f-string.

# %%
# type your code here

# %%
num_a = int(input("enter your 1st number here:"))
num_b = int(input("enter your 2nd number here"))

num_c = num_a + num_b

print(f"this is you sum" , num_c)
# Out:
# enter your 1st number here: 33
# enter your 2nd number here 33
# this is you sum 66

# %% [markdown]
# # 🔹 Q12 (Full Name + Upper/Lower)  User se first name aur last name lo aur:  1)  full name print karo  2) upper case 3)lower case

# %%
# type your code here

# %%
var_name = input("Please Enter Your Name:")

print(f"This your full name:" , var_name)
print(f"This your name in capital letters" , var_name.upper())
print(f"This is your name in small letters" , var_name.lower())
# Out:
# Please Enter Your Name: ghulam zainulabideen
# This your full name: ghulam zainulabideen
# This your name in capital letters GHULAM ZAINULABIDEEN
# This is your name in small letters ghulam zainulabideen

# %% [markdown]
# # 🔹 Q13 (Sentence Formatting) User se aik sentence lo aur usay: 1) title case 2)capitalize  3)length print karo

# %%
# type your code here

# %%
sen_a = input("Apni marzi ka sentence likye:")

print(sen_a.title())
print(sen_a.capitalize())
print(len(sen_a))
# Out:
# Apni marzi ka sentence likye: mera namm murtaza hai, aur main eik pakistan ka citizen hun, aur aj sy mane Ai aur data science ki study start krdi hai
# Mera Namm Murtaza Hai, Aur Main Eik Pakistan Ka Citizen Hun, Aur Aj Sy Mane Ai Aur Data Science Ki Study Start Krdi Hai
# Mera namm murtaza hai, aur main eik pakistan ka citizen hun, aur aj sy mane ai aur data science ki study start krdi hai
# 119

# %% [markdown]
# # 🔹 Q14 (Marks + Total) User se 3 subjects ke marks lo aur total print karo using f-string.

# %%
# type your code here

# %%
var_mark1 = int(input("Please Enter your English marks"))
var_mark2 = int(input("Please Enter your Urdu marks"))
var_mark3 = int(input("Please Enter your Math marks"))

total_marks = var_mark1 + var_mark2 + var_mark3

print(f"apke total marks hain" , total_marks)
# Out:
# Please Enter your English marks 50
# Please Enter your Urdu marks 70
# Please Enter your Math marks 60
# apke total marks hain 180

# %% [markdown]
# # 🔹 Q15 (Simple Bank Info / ID Card Style ) User se: 1) name  2)CNIC  3)balance lo aur formatted output dikhao

# %%
# type your code here

# %%
client_name = input("Please Enter Your Name Here")
client_cnic = input("Please Ennter Your CNIC Number Here:")
clinet_bal = int(input("please Enter Your Account Balance Here"))


print("-" * 30)
print("Your Bank Details")
print("-" * 30)
print(f" Your Name:           {client_name}")
print(f" Cnic Number:         {client_cnic}")
print(f" Account Balance:     {clinet_bal}")
# Out:
# Please Enter Your Name Here fiza baneen khan
# Please Ennter Your CNIC Number Here: 505005050500505
# please Enter Your Account Balance Here 10101010101010101
# ------------------------------
# Your Bank Details
# ------------------------------
#  Your Name:           fiza baneen khan
#  Cnic Number:         505005050500505
#  Account Balance:     10101010101010101

# %%
eve1 = "murtaza ali khan"
reverse_eve1 = eve1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 eve1 = "murtaza ali khan"
# ----> 2 reverse_eve1 = "".join(reverse(eve1))
#
# NameError: name 'reverse' is not defined
