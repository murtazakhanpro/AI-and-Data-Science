# %%
print("Kinldy Enter Your Items: ")


#while True:
    x = int(input("Enter the price"))
    sum = x+sum
   ''' if x = "q":
        return"Press Q to End"
        print(f'''Total so far = {sum}''')
       # break
    #else:
# Out:
#   File <string>:7
#     ''' if x = "q":
#                    ^
# IndentationError: unindent does not match any outer indentation level
