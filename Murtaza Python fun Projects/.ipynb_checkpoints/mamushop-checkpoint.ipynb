# %% [markdown]
# ## More On Functions

# %%
mamushop = [{'item':'floor', 'price':100 , 'inventory': 250},
            {'item':'sugar', 'price':180 , 'inventory': 500},
            {'item':'rice', 'price':300 , 'inventory': 500},
            {'item':'oil', 'price':500 , 'inventory': 1000},
            {'item':'ghee', 'price':500 , 'inventory': 500},
            {'item':'tea', 'price':400 , 'inventory': 100},
            {'item':'soap', 'price':200 , 'inventory': 50},
            {'item':'salt', 'price':50 , 'inventory': 100}]

# %%
cart = {}
while True:
    item_name = input("Enter the item you want to buy or press Q to exit").lower()
    if item_name == 'q':
        print("Thank You For Shopping")
        print(cart)
        break
    else:
        for a in mamushop:
            if a['item'] != item_name:
                print(f"{item_name} Not Availble")
                continue

            print(f"{item_name} {a['price']} ka hay")
            quantity = float(input("Kitna Chahiye hy?"))
            if a['inventory'] >= quantity:
                cart[item_name] = a['price'] * quantity
                a['inventory']-= quantity
            else:
                print(f"{item_name} itna nhi hy ")
                


        else:
            print("Thanks")
# Out:
# Enter the item you want to buy or press Q to exit soap
# soap Not Availble
# Enter the item you want to buy or press Q to exit floor
# floor 100 ka hay
# Kitna Chahiye hy? 20
# floor Not Availble
# Enter the item you want to buy or press Q to exit rice
# rice Not Availble
# Enter the item you want to buy or press Q to exit q
# Thank You For Shopping
# {'floor': 2000.0}

# %%
mamushop
# Out:
# [{'item': 'floor', 'price': 100, 'inventory': 250},
#  {'item': 'sugar', 'price': 180, 'inventory': 500},
#  {'item': 'rice', 'price': 300, 'inventory': 480.0},
#  {'item': 'oil', 'price': 500, 'inventory': 1000},
#  {'item': 'ghee', 'price': 500, 'inventory': 500},
#  {'item': 'tea', 'price': 400, 'inventory': 100},
#  {'item': 'soap', 'price': 200, 'inventory': 50},
#  {'item': 'salt', 'price': 50, 'inventory': 100}]

# %%
for a in range(10):
    if a >5:
        break
    print(a)
else:
    print("Bye Bye Loop")
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
cart
# Out:
# {'rice': 6000.0}
