# %% [markdown]
# Hello to everyOne aj hum log python main dictionaries k bare main sekhain gy

# %%
Chai_flavors = ["Spicy" , "zesty", "Ajeebi"]

# %%
print(Chai_flavors)

# %%
chai_types = {"Masala":"Spicy" , "Ginger":"zesty" , "Green":"Mild"}

# %%
chai_types
# Out:
# {'Masala': 'Spicy', 'Ginger': 'zesty', 'Green': 'Mild'}

# %%
chai_types["Masala"]
# Out:
# 'Spicy'

# %%
chai_types.get("Ginger")
# Out:
# 'zesty'

# %%
chai_types
# Out:
# {'Masala': 'Spicy', 'Ginger': 'zesty', 'Green': 'Mild'}

# %%
chai_types["Green"] = "Fresh"

# %%
chai_types
# Out:
# {'Masala': 'Spicy', 'Ginger': 'zesty', 'Green': 'Fresh'}

# %%
chai_types
# Out:
# {'Masala': 'Spicy', 'Ginger': 'zesty', 'Green': 'Fresh'}

# %%
for chai in chai_types:
    print(chai)
# Out:
# Masala
# Ginger
# Green

# %%
for chai in chai_types:
    print(chai, chai_types[chai])
# Out:
# Masala Spicy
# Ginger zesty
# Green Fresh

# %%
for key, value in chai_types.items():
    print(key , value)
# Out:
# Masala Spicy
# Ginger zesty
# Green Fresh

# %%
if "Masala" in chai_types:
    print("I have masla chai")
# Out:
# I have masla chai

# %%
print(len(chai_types))
# Out:
# 3

# %%
chai_types
# Out:
# {'Masala': 'Spicy', 'Ginger': 'zesty', 'Green': 'Fresh'}

# %%
chai_types["Earl Grey"] = "Citrus"
chai_types
# Out:
# {'Masala': 'Spicy', 'Ginger': 'zesty', 'Green': 'Fresh', 'Earl Grey': 'Citrus'}

# %% [markdown]
# #Pop method Sirf defined key value ko remove krta hai

# %%
chai_types.pop("Ginger")
# Out:
# 'zesty'

# %%
chai_types
# Out:
# {'Masala': 'Spicy', 'Green': 'Fresh'}

# %% [markdown]
# #Pop Item Last value ko remove kr k return krwa deta hai

# %%
chai_types.popitem()
# Out:
# ('Earl Grey', 'Citrus')

# %%
chai_types
# Out:
# {'Masala': 'Spicy', 'Green': 'Fresh'}

# %%
del chai_types["Green"]

# %%
chai_types
# Out:
# {'Masala': 'Spicy'}

# %%
chai_types_copy = chai_types.copy()

# %%
chai_types_copy
# Out:
# {'Masala': 'Spicy'}

# %% [markdown]
# Nested Dictionaries bhi ho sakti hain isko thora use krne lea bohat he use full hota hai

# %%
tea_shop = {
    "chai":{"masla":"Spicy" , "Ginger":"Zesty"},
    "Tea" :{"Green": "Mild", "Black":"Strong"}
}

# %%
tea_shop
# Out:
# {'chai': {'masla': 'Spicy', 'Ginger': 'Zesty'},
#  'Tea': {'Green': 'Mild', 'Black': 'Strong'}}

# %%
tea_shop["chai"]
# Out:
# {'masla': 'Spicy', 'Ginger': 'Zesty'}

# %%
tea_shop["Tea"]
# Out:
# {'Green': 'Mild', 'Black': 'Strong'}

# %%
tea_shop[]
# Out:
#   Cell In[42], line 1
#     tea_shop[]
#              ^
# SyntaxError: invalid syntax

# %%
tea_shop["chai"]["Ginger"]
# Out:
# 'Zesty'
