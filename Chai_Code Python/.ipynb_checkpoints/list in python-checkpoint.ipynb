# %% [markdown]
# # List in python

# %%
tea_varities = ["Black" , "Green" , "OOolong" , "White"]

# %%
print(tea_varities)
# Out:
# ['Black', 'Green', 'OOolong', 'White']

# %%
print(tea_varities[1])
# Out:
# Green

# %%
print(tea_varities[-1])

# %%
print(tea_varities[1:3])
# Out:
# ['Green', 'OOolong']

# %%
print(tea_varities[:2])
# Out:
# ['Black', 'Green']

# %%
print(tea_varities[2:1])
# Out:
# []

# %%
tea_varities[3]="Herbal"

# %%
tea_varities
# Out:
# ['Black', 'Green', 'OOolong', 'Herbal']

# %%
tea_varities[1:2]
# Out:
# ['Green']

# %%
tea_varities
# Out:
# ['Black', 'Green', 'OOolong', 'Herbal']

# %%
tea_varities[3] = "white"

# %%
tea_varities
# Out:
# ['Black', 'Green', 'OOolong', 'white']

# %%
tea_varities[1:1]
# Out:
# []

# %%
tea_varities[1:1] = ["Test", "Test"]

# %%
tea_varities
# Out:
# ['Black', 'Test', 'Test', 'Green', 'OOolong', 'white']

# %%
tea_varities[1:2]
# Out:
# ['Test']

# %%
tea_varities[1:3]
# Out:
# ['Test', 'Test']

# %%
tea_varities[1:4]
# Out:
# ['Test', 'Test', 'Green']

# %%
tea_varities[1:3] = []

# %%
tea_varities.reverse()
tea_varities
# Out:
# ['Black', 'Green', 'OOolong', 'white']

# %%
tea_varities[2] = "Masala"

# %%
tea_varities
# Out:
# ['Black', 'Green', 'Masala', 'white']

# %% [markdown]
# # For Loops

# %%
for tea in tea_varities:
    print(tea)
# Out:
# Black
# Green
# Masala
# white

# %%
for tea in tea_varities:
    print(tea, end="==")
# Out:
# Black==Green==Masala==white==

# %%
tea_varities
# Out:
# ['Black', 'Green', 'Masala', 'white']

# %%
if "Oolong" in tea_varities:
    print("I have Oolong tea")

# %%
tea_varities.append('Oolong')

# %%
tea_varities
# Out:
# ['Black', 'Green', 'Masala', 'white', 'Oolong']

# %%
if "Oolong" in tea_varities:
    print("I have Oolong tea")
# Out:
# I have Oolong tea

# %%
tea_varities
# Out:
# ['Black', 'Green', 'Masala', 'white', 'Oolong']

# %% [markdown]
# # pop method sirf last item remove kr deta hai

# %%
tea_varities.pop()
# Out:
# 'Oolong'

# %%
tea_varities
# Out:
# ['Black', 'Green', 'Masala', 'white']

# %%
tea_varities.remove("Green")

# %%
tea_varities
# Out:
# ['Black', 'Masala', 'white']

# %%
tea_varities.insert(1, "Green")

# %%
tea_varities
# Out:
# ['Black', 'Green', 'Masala', 'white']

# %%
tea_varities_copy = tea_varities.copy()

# %%
id(tea_varities)
id(tea_varities_copy)
# Out:
# 140067622396096

# %%
id(tea_varities)
# Out:
# 140067622184512

# %%
tea_varities_copy.append("Lemon")

# %%
tea_varities
# Out:
# ['Black', 'Green', 'Masala', 'white']

# %%
tea_varities_copy
# Out:
# ['Black', 'Green', 'Masala', 'white', 'Lemon']

# %% [markdown]
# # List Comprehensions

# %%
squared_nums = [x**2 for x in range(10)]

# %%
squared_nums
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
range(10)
# Out:
# range(0, 10)

# %%
print(range(10))
# Out:
# range(0, 10)

# %%
y = range(10)

# %%
y
# Out:
# range(0, 10)

# %%
print(y)
# Out:
# range(0, 10)

# %%
squared_nums = [x**2 for x in range(10)]

# %%
squared_nums
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %% [markdown]
# ### Python main hamesha last wala value nhi aata n-1

# %%
cube_num = [y**3 for y in range(5)]

# %%
cube_num
# Out:
# [0, 1, 8, 27, 64]
