# %% [markdown]
# string humain
# - single qoute ''
# - double qoute ""
# - triple qoute '''

# %%
chai = "Lemon Chai"
chai
# Out:
# 'Lemon Chai'

# %%
firstChar = chai[0]

# %%
print(firstChar)
# Out:
# L

# %%
chai = "Masla Chai"
print(chai)
# Out:
# Masla Chai

# %%
slice_chai = chai[0:8]
print(slice_chai)
# Out:
# Masla Ch

# %%
slice_chai = chai[0:6]

# %%
print(slice_chai)
# Out:
# Masla

# %%
slice_chai = chai[0:4:2]

# %%
slice_chai
# Out:
# 'Ms'

# %%
num_list = "0123456789"

# %%
num_list[0]
# Out:
# '0'

# %%
num_list[:9]
# Out:
# '012345678'

# %%
num_list[::2]
# Out:
# '02468'

# %%
num_list[::-1]
# Out:
# '9876543210'

# %%
num_list[::3]
# Out:
# '0369'

# %%
print(chai)
# Out:
# Masla Chai

# %%
print(chai.lower())
# Out:
# masla chai

# %%
print(chai.upper())
# Out:
# MASLA CHAI

# %%
chai =    "   Masala Chai   "
print(chai)
# Out:
#    Masala Chai

# %%
print(chai.strip())
# Out:
# Masala Chai

# %%
chai = "Lemon Chai"

# %%
print(chai.replace("Lemon" , "Ginger"))
# Out:
# Ginger Chai

# %%
chai
# Out:
# 'Lemon Chai'

# %%
chai = "Lemon , Ginger , Masala , Mint"

# %%
print(chai.split(", "))
# Out:
# ['Lemon ', 'Ginger ', 'Masala ', 'Mint']

# %%
chai = "Masala Chai"

# %%
print(chai.find("Chai"))
# Out:
# 7

# %%
chai = "Masala chai chai chai"
print(chai.count("chai"))
# Out:
# 3

# %%
chai_type = "Masala"
quantity = 2

# %%
order = "I ordered {} cups of {} chai"

# %%
print(order.format(quantity , chai_type))
# Out:
# I ordered 2 cups of Masala chai

# %%
chai_variety = ["Lemon", "Masala" , "Ginger"]

# %% [markdown]
# <!-- list to string conversion k lea hum join use krte hain -->

# %% [markdown]
# list to string k lea (join) method use hota hai

# %%
print(chai_variety)
# Out:
# ['Lemon', 'Masala', 'Ginger']

# %%
print(", ".join(chai_variety))
# Out:
# Lemon, Masala, Ginger

# %%
print(len(chai_variety))
# Out:
# 3

# %%
print(len(chai))
# Out:
# 21

# %%
print(chai)
# Out:
# Masala chai chai chai

# %%
for letter in chai:
    print(letter)
# Out:
# M
# a
# s
# a
# l
# a
#
# c
# h
# a
# i
#
# c
# h
# a
# i
#
# c
# h
# a
# i

# %%
chai = "He said, \"Masala chai is awsome\"  "

# %%
print(chai)
# Out:
# He said, "Masala chai is awsome"

# %%
chai = "Masala\nchai"
print(chai)
# Out:
# Masala
# chai

# %%
chai = r"Masala\nchai"
print(chai)
# Out:
# Masala\nchai

# %%
chai = r"c:\user\pwd"

# %% [markdown]
# use r keyword yeh hota hai raw key isy windows k path ka issue nhi ata

# %%
chai
# Out:
# 'c:\\user\\pwd'

# %%
chai = r"c:\user\pwd"
print(chai)
# Out:
# c:\user\pwd

# %%
chai
# Out:
# 'c:\\user\\pwd'

# %%
chai = "Masala chai"

# %%
print(chai)
# Out:
# Masala chai

# %%
print("Masala" in chai)
# Out:
# True

# %%
print("Masalaa" in chai)
# Out:
# False
