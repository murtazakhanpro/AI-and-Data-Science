# %% [markdown]
# #Questions on Conditionals
# - age group catagorization

# %%
score = 100
score
# Out:
# 100

# %%
score = int(input("Give me a score value"))

# %%
score
# Out:
# 200

# %%
age = 75
if (age < 13):
    print('child')
elif (age < 18):
    print('Teenage')
elif (age<60):
    print("Adult")
else:
    print("Senior Citizen")
# Out:
# Senior Citizen
