# %% [markdown]
# #  1) Aik variable banao aur apna name print karo

# %%
var1 = "murtaza"

# %%
print(var1)
# Out:
# murtaza

# %% [markdown]
# # 2) Aik variable banao aur favourite color print karo

# %%
fav_col  = input("Please Enter Your Favorit Color")

print(f'''your Favorit Color is {fav_col} ''')
# Out:
# Please Enter Your Favorit Color white
# your Favorit Color is white

# %% [markdown]
# # 3) Do variables banao: name aur age print karo

# %%
name = input("Please enter your name here")
age = int(input("please enter your age here"))

print(f'''Hello my name is {name}
          and i'm {age} year old
        
        ''')
# Out:
# Please enter your name here murtaza
# please enter your age here 28
# Hello my name is murtaza
#           and i'm 28 year old

# %% [markdown]
# # 4) Do numbers ko add karo
#   # first user  input lena
#   # secound user input lo
#   # dono ko add kr kai jawab aik naye variables mai dalo
#   # phr is varibales ko and mai print karo

# %%
num1 = int(input("Please Enter your 1st number"))
num2 = int(input("Please Enter Your 2nd number"))

num3  = num1 + num2

print(f'''

your first number was     {num1}
your second number was  + {num2}
================================
Total sum is               {num3}




''')
# Out:
# Please Enter your 1st number 23
# Please Enter Your 2nd number 34
# your first number was     23
# your second number was  + 34
# ...
# Total sum is               57

# %% [markdown]
# # 5) Aik variable hobby banao aur print karo apni hobby

# %%
hobby = input("please enter your hoby")

print(f'''your favorit hoby is  {hobby}''' )
# Out:
# please enter your hoby programming
# your favorit hoby is  programming

# %% [markdown]
# # 6) Do numbers subtract karo
#    # first aik user input lo
#    # secound varibles mai lo
#    # print karo

# %%
num1 = int(input("Please Enter your 1st number"))
num2 = int(input("Please Enter Your 2nd number"))

num3  = num1 - num2

print(f'''

your first number was     {num1}
your second number was  - {num2}
================================
Total subtraction is      {num3}

''')
# Out:
# Please Enter your 1st number 23
# Please Enter Your 2nd number 33
# your first number was     23
# your second number was  - 33
# ...
# Total subtraction is      -10

# %% [markdown]
# # 7) User sai input lo aur name  print kro

# %%
nam = input("Apna nam batao")

print("apka nam " + nam )
# Out:
# Apna nam batao murtaza
# apka nam murtaza

# %% [markdown]
# # 8) User sai str input lo aur 5 dafa city print karo

# %%
city = input("plase enter your city of choice")

mul_city = city*5


print(mul_city)
# Out:
# plase enter your city of choice jehlum
# jehlumjehlumjehlumjehlumjehlum

# %% [markdown]
# # 9) User se age input lo aur print karo

# %%
age = int(input("please tell me your age"))

print(f'''your age is  {age}''')
# Out:
# please tell me your age 28
# your age is  28

# %% [markdown]
# # 10) User se 2 numbers input lo aur unka sum print karo

# %%
num1 = int(input("Please Enter your 1st number"))
num2 = int(input("Please Enter Your 2nd number"))

num3  = num1 + num2

print(f'''

your first number was     {num1}
your second number was  + {num2}
================================
Total sum is               {num3}




''')
# Out:
# Please Enter your 1st number 34
# Please Enter Your 2nd number 54
# your first number was     34
# your second number was  + 54
# ...
# Total sum is               88

# %% [markdown]
# # 11) User input  se number lo aur check karo ke wo even hai ya odd
# # input lo
# # second yeh kai varibale mai check kro kai even hai ya ni
# # print kro

# %%
de_num = int(input("please enter your numeber"))
if de_num % 2 == 0:
    print(f'''given {de_num} is even''')
else:
    print(f'''given {de_num} is odd''')
# Out:
# please enter your numeber 23
# given 23 is odd

# %% [markdown]
# # 12) user sai Do numbers varibale mai  lo aur check karo kya pehla number bada hai
# # first variable mai number lo
# # second variables mai number lo
# # and print karo ky kon sa number bara hai

# %%
num1 = int(input("please enter you 1st number"))
num2 = int(input("please enter you 2nd number"))

if num1 > num2:
    print(f'''1st number is {num1} is greater than ''')
else:
    print(f'''2nd number is {num2} is greater''')
# Out:
# please enter you 1st number 23
# please enter you 2nd number 32
# 2nd number is 32 is greater

# %% [markdown]
# # 13) Check karo: number 5 number 10 sy bara hai ya ni?

# %%
n1 = 5 # isme hum input bhi karwa satke hain (lakin uske lea input function use hoga)
n2 = 10 # isme hum input bhi karwa satke hain (lakin uske lea input function use hoga)

if n1 > n2:
    print(f'''number {n1} bara hai {n2} say''')
else:
        print(f'''number {n2} bara hai {n1} say''')
# Out:
# number 10 bara hai 5 say

# %% [markdown]
# # 14:3 variables bano
# # a
# # b
# # c
# # teno variables mai numbers hony chiya
# # teno varibales ko plus(+) karo and unka sum print karo

# %%
a = int(input("please enter your 1st number"))
b = int(input("please enter your 2nd number"))
c = int(input("please enter your 3rd number"))

d= a+b+c

if not isinstance(a,int) or not isinstance(b, int) or not isinstance(c , int):
    print("teno variables numbers hone chahiye")
else:
    print(f'''Apka sum hua hai {d}''')
# Out:
# please enter your 1st number 23
# please enter your 2nd number 3
# please enter your 3rd number 32
# teno variables numbers hone chahiye

# %% [markdown]
# # 15) User se name aur city input lo aur ek sentence print karo

# %%
nam1 = input("Please enter your name here")
nam2 = input("please enter your city here")


print(f'''
your name is {nam1}
your city is {nam2}
''')
# Out:
# Please enter your name here Murtaza
# please enter your city here Karachi
# your name is Murtaza
# your city is Karachi

# %% [markdown]
# # 16: 3 different number lo
# # and un 3 variables ko apas mai - karo and answer 5 print karo

# %%
a = 20
b = 10
c = 5

answer = a-b-c

print(answer)
# Out:
# 5

# %% [markdown]
# # 17: aik variale bano (s):
# # and usky ander apna nam input lo
# # phir apny nam ky sth hello add kr ky us ko print karo

# %%
s = input("enter your name")

print(f'''Hello {s}''')
# Out:
# enter your name fiza
# Hello fiza

# %% [markdown]
# #

# %% [markdown]
# # 18: user sy aik number input lo
# # us number ky ander 90 add karo and usko print karo and uska answer 100 ana chiya

# %%
while True:
    number = int(input("Aisa number enter karein jis mein 90 add karne se 100 aaye: "))
    
    if number + 90 == 100:
        print("Bilkul sahi! Result is: 100")
        break  
    else:
        print("Ghalat! Dobara koshish karein.")
# Out:
# Aisa number enter karein jis mein 90 add karne se 100 aaye:  8
# Ghalat! Dobara koshish karein.
# Aisa number enter karein jis mein 90 add karne se 100 aaye:  33
# Ghalat! Dobara koshish karein.
# Aisa number enter karein jis mein 90 add karne se 100 aaye:  10
# Bilkul sahi! Result is: 100

# %% [markdown]
# #  19: user sy 2 inputs lo
# # a
# # b
# # print karo True agar (a) bara hai (>) b sy toh

# %%
while True:

x = int(input("please enter your number"))
y = int(input("please enter your number"))

if a>b:
    print("True")
else:
    print("try again")
# Out:
# please enter your number 23
# please enter your number 43
# True

# %% [markdown]
# # 20 : 1 int user input lo and uska exponent print kar do

# %%
x = int(input("Enter the number of your choice"))
y = x**x

print(f"this is exponant of your number {y}")
# Out:
# Enter the number of your choice 3
# this is exponant of your number 27
