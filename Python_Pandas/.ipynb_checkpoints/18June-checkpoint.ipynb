# %% [markdown]
# # Data Cleaning
#     - Data Type Issues
#     - Missing Values
#     - Duplicate Values
#     - Outlier Values
#     - Misc issues

# %%
import pandas as pd

# %%
data = pd.read_excel("employee.xlsx")

# %%
data
# Out:
#     Serial  Emp_ID Designation  Department   Age    Salary
# 0        1    1101     Manager    Accounts  50.0  200000.0
# 1        2    1107     Officer          IT  30.0   80000.0
# 2        3    1203     Officer          HR  28.0       NaN
# 3        4    1005     Manager          HR  45.0  120000.0
# 4        5    2123  Office Boy    Accounts  27.0   45000.0
# 5        6    2451  Accountant         NaN  34.0  100000.0
# 6        7    1111  Accountant    Accounts   NaN  110000.0
# 7        8    1001     Officer          IT  25.0   75000.0
# 8        9    1234     Manager          IT  23.0       NaN
# 9       10    2156    Engineer  Production  45.0   89000.0
# 10      11    6543     Officer  Production  29.0  100000.0
# 11      12    3214  Accountant     Account  49.0  123000.0
# 12      13    2156    Engineer  Production  45.0   89000.0
# 13      14    1098     Officer          IT  25.0  100000.0
# 14      15    2912     Officer          IT  31.0   90000.0
# 15      16    1222     Officer         NaN  25.0       NaN
# 16      17    2156    Engineer  Production  45.0   89000.0
# 17      18    2123  Office Boy    Accounts  27.0   45000.0
# 18      19    1005     Manager          HR  45.0  120000.0
# 19      20    2123  Office Boy    Accounts  27.0   45000.0
# 20      21    6543     Officer  Production  29.0  100000.0
# 21      22    3214  Accountant     Account  49.0  123000.0
# 22      23    2156    Engineer  Production  45.0   89000.0
# 23      24    1098     Officer          IT  25.0  100000.0
# 24      25    2156    Engineer  Production  45.0   89000.0
# 25      26    2123  Office Boy    Accounts  27.0   45000.0

# %%
data.drop('Serial', axis=1,inplace=True)

# %% [markdown]
# ### Handling Missing Values
#    - Drop all records having mising data
#    - Drop all columns habving missing data
#    - Fill missing
#          - hard coded value
#          - calculate statiscally mean, median ,mode
#     - bfill , ffill

# %%
data.dropna()  # dropping all row having any NAN value
# Out:
#     Emp_ID Designation  Department   Age    Salary
# 0     1101     Manager    Accounts  50.0  200000.0
# 1     1107     Officer          IT  30.0   80000.0
# 3     1005     Manager          HR  45.0  120000.0
# 4     2123  Office Boy    Accounts  27.0   45000.0
# 7     1001     Officer          IT  25.0   75000.0
# 9     2156    Engineer  Production  45.0   89000.0
# 10    6543     Officer  Production  29.0  100000.0
# 11    3214  Accountant     Account  49.0  123000.0
# 12    2156    Engineer  Production  45.0   89000.0
# 13    1098     Officer          IT  25.0  100000.0
# 14    2912     Officer          IT  31.0   90000.0
# 16    2156    Engineer  Production  45.0   89000.0
# 17    2123  Office Boy    Accounts  27.0   45000.0
# 18    1005     Manager          HR  45.0  120000.0
# 19    2123  Office Boy    Accounts  27.0   45000.0
# 20    6543     Officer  Production  29.0  100000.0
# 21    3214  Accountant     Account  49.0  123000.0
# 22    2156    Engineer  Production  45.0   89000.0
# 23    1098     Officer          IT  25.0  100000.0
# 24    2156    Engineer  Production  45.0   89000.0
# 25    2123  Office Boy    Accounts  27.0   45000.0

# %%
data.dropna(axis=1)
# Out:
#     Emp_ID Designation
# 0     1101     Manager
# 1     1107     Officer
# 2     1203     Officer
# 3     1005     Manager
# 4     2123  Office Boy
# 5     2451  Accountant
# 6     1111  Accountant
# 7     1001     Officer
# 8     1234     Manager
# 9     2156    Engineer
# 10    6543     Officer
# 11    3214  Accountant
# 12    2156    Engineer
# 13    1098     Officer
# 14    2912     Officer
# 15    1222     Officer
# 16    2156    Engineer
# 17    2123  Office Boy
# 18    1005     Manager
# 19    2123  Office Boy
# 20    6543     Officer
# 21    3214  Accountant
# 22    2156    Engineer
# 23    1098     Officer
# 24    2156    Engineer
# 25    2123  Office Boy

# %%
data.dropna(how='any',axis=1)
data.dropna(how='all', axis=1)
data.dropna(subset=['Department','Salary'],how='all',axis=0)
# Out:
#     Emp_ID Designation  Department   Age    Salary
# 0     1101     Manager    Accounts  50.0  200000.0
# 1     1107     Officer          IT  30.0   80000.0
# 2     1203     Officer          HR  28.0       NaN
# 3     1005     Manager          HR  45.0  120000.0
# 4     2123  Office Boy    Accounts  27.0   45000.0
# 5     2451  Accountant         NaN  34.0  100000.0
# 6     1111  Accountant    Accounts   NaN  110000.0
# 7     1001     Officer          IT  25.0   75000.0
# 8     1234     Manager          IT  23.0       NaN
# 9     2156    Engineer  Production  45.0   89000.0
# 10    6543     Officer  Production  29.0  100000.0
# 11    3214  Accountant     Account  49.0  123000.0
# 12    2156    Engineer  Production  45.0   89000.0
# 13    1098     Officer          IT  25.0  100000.0
# 14    2912     Officer          IT  31.0   90000.0
# 16    2156    Engineer  Production  45.0   89000.0
# 17    2123  Office Boy    Accounts  27.0   45000.0
# 18    1005     Manager          HR  45.0  120000.0
# 19    2123  Office Boy    Accounts  27.0   45000.0
# 20    6543     Officer  Production  29.0  100000.0
# 21    3214  Accountant     Account  49.0  123000.0
# 22    2156    Engineer  Production  45.0   89000.0
# 23    1098     Officer          IT  25.0  100000.0
# 24    2156    Engineer  Production  45.0   89000.0
# 25    2123  Office Boy    Accounts  27.0   45000.0

# %% [markdown]
# ##### Filling Missing Data

# %%
data.Department
# Out:
# 0       Accounts
# 1             IT
# 2             HR
# 3             HR
# 4       Accounts
# 5            NaN
# 6       Accounts
# 7             IT
# 8             IT
# 9     Production
# 10    Production
# 11       Account
# 12    Production
# 13            IT
# 14            IT
# 15           NaN
# 16    Production
# 17      Accounts
# 18            HR
# 19      Accounts
# 20    Production
# 21       Account
# 22    Production
# 23            IT
# 24    Production
# 25      Accounts
# Name: Department, dtype: object

# %%
data.Department.fillna(data.Department.mode()[0])
# Out:
# 0       Accounts
# 1             IT
# 2             HR
# 3             HR
# 4       Accounts
# 5     Production
# 6       Accounts
# 7             IT
# 8             IT
# 9     Production
# 10    Production
# 11       Account
# 12    Production
# 13            IT
# 14            IT
# 15    Production
# 16    Production
# 17      Accounts
# 18            HR
# 19      Accounts
# 20    Production
# 21       Account
# 22    Production
# 23            IT
# 24    Production
# 25      Accounts
# Name: Department, dtype: object

# %%
data.Age.mean()
# Out:
# np.float64(35.0)

# %%
data.Age.median()
# Out:
# 30.0

# %%
data.Age.fillna(data.Age.median())
# Out:
# 0     50.0
# 1     30.0
# 2     28.0
# 3     45.0
# 4     27.0
# 5     34.0
# 6     30.0
# 7     25.0
# 8     23.0
# 9     45.0
# 10    29.0
# 11    49.0
# 12    45.0
# 13    25.0
# 14    31.0
# 15    25.0
# 16    45.0
# 17    27.0
# 18    45.0
# 19    27.0
# 20    29.0
# 21    49.0
# 22    45.0
# 23    25.0
# 24    45.0
# 25    27.0
# Name: Age, dtype: float64

# %%
data.Salary.fillna(data.Salary.median())
# Out:
# 0     200000.0
# 1      80000.0
# 2      90000.0
# 3     120000.0
# 4      45000.0
# 5     100000.0
# 6     110000.0
# 7      75000.0
# 8      90000.0
# 9      89000.0
# 10    100000.0
# 11    123000.0
# 12     89000.0
# 13    100000.0
# 14     90000.0
# 15     90000.0
# 16     89000.0
# 17     45000.0
# 18    120000.0
# 19     45000.0
# 20    100000.0
# 21    123000.0
# 22     89000.0
# 23    100000.0
# 24     89000.0
# 25     45000.0
# Name: Salary, dtype: float64

# %%
data.fillna({'Salary':data.Salary.median(), 
             'Age':data.Age.median(),
             'Department':data.Department.mode()[0],
             'Designation':data.Designation.mode()[0]
            }, inplace=True)

# %% [markdown]
# # Duplicate Data Removal
#     - A record is said to be duplicated if all columns have same value.
#     - We can customized this duplication criteria.

# %% [markdown]
# ##### Identify duplicate records / Filter out

# %%
data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# dtype: bool

# %%
# how many duplicate records are in data
data.duplicated().sum()
# Out:
# np.int64(11)

# %%
# all duplicate records 
data[data.duplicated()]
# Out:
#     Emp_ID Designation  Department   Age    Salary
# 12    2156    Engineer  Production  45.0   89000.0
# 16    2156    Engineer  Production  45.0   89000.0
# 17    2123  Office Boy    Accounts  27.0   45000.0
# 18    1005     Manager          HR  45.0  120000.0
# 19    2123  Office Boy    Accounts  27.0   45000.0
# 20    6543     Officer  Production  29.0  100000.0
# 21    3214  Accountant     Account  49.0  123000.0
# 22    2156    Engineer  Production  45.0   89000.0
# 23    1098     Officer          IT  25.0  100000.0
# 24    2156    Engineer  Production  45.0   89000.0
# 25    2123  Office Boy    Accounts  27.0   45000.0

# %%
# drops all duplicate records 
data.drop_duplicates(inplace=True)

# %%
data
# Out:
#     Emp_ID Designation  Department   Age    Salary
# 0     1101     Manager    Accounts  50.0  200000.0
# 1     1107     Officer          IT  30.0   80000.0
# 2     1203     Officer          HR  28.0   90000.0
# 3     1005     Manager          HR  45.0  120000.0
# 4     2123  Office Boy    Accounts  27.0   45000.0
# 5     2451  Accountant  Production  34.0  100000.0
# 6     1111  Accountant    Accounts  30.0  110000.0
# 7     1001     Officer          IT  25.0   75000.0
# 8     1234     Manager          IT  23.0   90000.0
# 9     2156    Engineer  Production  45.0   89000.0
# 10    6543     Officer  Production  29.0  100000.0
# 11    3214  Accountant     Account  49.0  123000.0
# 13    1098     Officer          IT  25.0  100000.0
# 14    2912     Officer          IT  31.0   90000.0
# 15    1222     Officer  Production  25.0   90000.0

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data[data.duplicated(subset=['Age','Designation'])]
# Out:
#     Emp_ID Designation  Department   Age    Salary
# 13    1098     Officer          IT  25.0  100000.0
# 15    1222     Officer  Production  25.0   90000.0

# %% [markdown]
# # Outlier:
#   - Box plot:
#      Five number Summary
#           - Min
#           - Max
#           - Median         >>> 50 percdentile
#           - Q1 (Quartile1) >> 25  percentile
#           - Q3 (Quartile) >>> 75  percentile

# %%
data
# Out:
#     Emp_ID Designation  Department   Age    Salary
# 0     1101     Manager    Accounts  50.0  200000.0
# 1     1107     Officer          IT  30.0   80000.0
# 2     1203     Officer          HR  28.0   90000.0
# 3     1005     Manager          HR  45.0  120000.0
# 4     2123  Office Boy    Accounts  27.0   45000.0
# 5     2451  Accountant  Production  34.0  100000.0
# 6     1111  Accountant    Accounts  30.0  110000.0
# 7     1001     Officer          IT  25.0   75000.0
# 8     1234     Manager          IT  23.0   90000.0
# 9     2156    Engineer  Production  45.0   89000.0
# 10    6543     Officer  Production  29.0  100000.0
# 11    3214  Accountant     Account  49.0  123000.0
# 13    1098     Officer          IT  25.0  100000.0
# 14    2912     Officer          IT  31.0   90000.0
# 15    1222     Officer  Production  25.0   90000.0

# %%
data.Age.min()
# Out:
# 23.0

# %%
data.Age.max()
# Out:
# 50.0

# %%
data.Age.mean()
# Out:
# np.float64(33.06666666666667)

# %%
data.Age.median()
# Out:
# 30.0

# %%
data.Age.std()
# Out:
# 9.353888928955598

# %%
import seaborn as sns

# %%
sns.boxplot(data.Age)
# Out:
# <Axes: ylabel='Age'>

# %%
import numpy as np
salary = np.array([49,50,40,35,50,60,67,80,300,500])
salary
# Out:
# array([ 49,  50,  40,  35,  50,  60,  67,  80, 300, 500])

# %%
salary.mean()
# Out:
# np.float64(123.1)

# %%
np.median(salary)
# Out:
# np.float64(55.0)

# %%
data.Salary.mean()
# Out:
# np.float64(100133.33333333333)

# %%
data.Salary.median()
# Out:
# 90000.0

# %%
sns.boxplot(data.Salary)
# Out:
# <Axes: ylabel='Salary'>

# %% [markdown]
# ![image.png](attachment:86b35d3f-87ec-4e82-96d8-42386ffd7a33.png)

# %% [markdown]
# lower_boundary: minumum
# upper_boundary: maximum
#
# Minimum = (Q1+1.5)*IQR
# Maximum =  (Q3-1.5)*IQR
# IQR = Q3-Q1

# %%
Q1 = np.percentile(data.Salary, 25)

# %%
Q1
# Out:
# np.float64(89500.0)

# %%
Q3 = np.percentile(data.Salary, 75)
Q3
# Out:
# np.float64(105000.0)

# %%
IQR = Q3-Q1
IQR
# Out:
# np.float64(15500.0)

# %%
lb = Q1-1.5*IQR
ub = Q3+1.5*IQR

# %%
lb
# Out:
# np.float64(66250.0)

# %%
ub
# Out:
# np.float64(128250.0)

# %%
data[(data.Salary<=lb) | (data.Salary>=ub)]
# Out:
#    Emp_ID Designation Department   Age    Salary
# 0    1101     Manager   Accounts  50.0  200000.0
# 4    2123  Office Boy   Accounts  27.0   45000.0

# %%
def detect_outlier(data):
    Q1 = np.percentile(data, 25)
    Q3 = np.percentile(data, 75)
    IQR = Q3-Q1
    lb = Q1-1.5*IQR
    ub = Q3+1.5*IQR
    return lb,ub

# %%
detect_outlier(data.Salary)[0]
detect_outlier(data.Salary)[1]
# Out:
# np.float64(128250.0)

# %%
data[(data.Salary<=detect_outlier(data.Salary)[0]) | (data.Salary>=detect_outlier(data.Salary)[1])]
# Out:
#    Emp_ID Designation Department   Age    Salary
# 0    1101     Manager   Accounts  50.0  200000.0
# 4    2123  Office Boy   Accounts  27.0   45000.0

# %%
data[(data.Age<=detect_outlier(data.Age)[0]) | (data.Age>=detect_outlier(data.Age)[1])]
# Out:
# Empty DataFrame
# Columns: [Emp_ID, Designation, Department, Age, Salary]
# Index: []

# %%
detect_outlier(data.Salary)
# Out:
# (np.float64(66250.0), np.float64(128250.0))

# %%
data[(data.Salary<=detect_outlier(data.Salary)[0] ) | (data.Salary>=detect_outlier(data.Salary)[1])]
# Out:
#    Emp_ID Designation Department   Age    Salary
# 0    1101     Manager   Accounts  50.0  200000.0
# 4    2123  Office Boy   Accounts  27.0   45000.0

# %%
np.array([1,2,3,4,5])
# Out:
# array([1, 2, 3, 4, 5])

# %%
import pandas as pd
data = pd.read_csv('car_data.csv')
data.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
data.shape
# Out:
# (892, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
data.isna().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    50
# fuel_type     53
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(4)

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (798, 6)

# %%
data.name = data.name.str.split().str[0:3].str.join(' ')

# %%
data
# Out:
#                        name    company  year          Price  kms_driven  \
# 0       Hyundai Santro Xing    Hyundai  2007         80,000  45,000 kms
# 1       Mahindra Jeep CL550   Mahindra  2006       4,25,000      40 kms
# 2        Maruti Suzuki Alto     Maruti  2018  Ask For Price  22,000 kms
# 3         Hyundai Grand i10    Hyundai  2014       3,25,000  28,000 kms
# 4    Ford EcoSport Titanium       Ford  2014       5,75,000  36,000 kms
# ..                      ...        ...   ...            ...         ...
# 887                      Ta       Tara  zest       3,10,000         NaN
# 888            Tata Zest XM       Tata  2018       2,60,000  27,000 kms
# 889      Mahindra Quanto C8   Mahindra  2013       3,90,000  40,000 kms
# 890         Honda Amaze 1.2      Honda  2014       1,80,000      Petrol
# 891      Chevrolet Sail 1.2  Chevrolet  2014       1,60,000      Petrol
#
#     fuel_type
# 0      Petrol
# 1      Diesel
# 2      Petrol
# 3      Petrol
# 4      Diesel
# ..        ...
# 887       NaN
# 888    Diesel
# 889    Diesel
# 890       NaN
# 891       NaN
#
# [798 rows x 6 columns]

# %%
data.year.unique()
# Out:
# array(['2007', '2006', '2018', '2014', '2015', '2012', '2013', '2016',
#        '2010', '2017', '2008', '2011', '2019', '2009', '2005', '2000',
#        '...', '150k', 'TOUR', '2003', 'r 15', '2004', 'Zest', '/-Rs',
#        'sale', '1995', 'ara)', '2002', 'SELL', '2001', 'tion', 'odel',
#        '2 bs', 'arry', 'Eon', 'o...', 'ture', 'emi', 'car', 'able', 'no.',
#        'd...', 'SALE', 'digo', 'sell', 'd Ex', 'n...', 'e...', 'D...',
#        ', Ac', 'go .', 'k...', 'o c4', 'zire', 'cent', 'Sumo', 'cab',
#        't xe', 'EV2', 'r...', 'zest'], dtype=object)

# %%
'150k'.isnumeric()
# Out:
# False

# %%
data2 = data[(data.year.str.isnumeric())]

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 749 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        749 non-null    object
#  1   company     749 non-null    object
#  2   year        749 non-null    object
#  3   Price       749 non-null    object
#  4   kms_driven  748 non-null    object
#  5   fuel_type   745 non-null    object
# dtypes: object(6)
# memory usage: 41.0+ KB

# %%
data2.year = data2.year.astype(int)
# Out:
# C:\Users\Teacher\AppData\Local\Temp\ipykernel_4908\3704337464.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2.year = data2.year.astype(int)

# %%
data.Price.unique()
# Out:
# array(['80,000', '4,25,000', 'Ask For Price', '3,25,000', '5,75,000',
#        '1,75,000', '1,90,000', '8,30,000', '2,50,000', '1,82,000',
#        '3,15,000', '4,15,000', '3,20,000', '10,00,000', '5,00,000',
#        '3,50,000', '1,60,000', '3,10,000', '75,000', '1,00,000',
#        '2,90,000', '95,000', '1,80,000', '3,85,000', '1,05,000',
#        '6,50,000', '6,89,999', '4,48,000', '5,49,000', '5,01,000',
#        '4,89,999', '2,80,000', '3,49,999', '2,84,999', '3,45,000',
#        '4,99,999', '2,35,000', '2,49,999', '14,75,000', '3,95,000',
#        '2,20,000', '1,70,000', '85,000', '2,00,000', '5,70,000',
#        '1,10,000', '4,48,999', '18,91,111', '1,59,500', '3,44,999',
#        '4,49,999', '8,65,000', '6,99,000', '3,75,000', '2,24,999',
#        '12,00,000', '1,95,000', '3,51,000', '2,40,000', '90,000',
#        '1,55,000', '6,00,000', '1,89,500', '2,10,000', '3,90,000',
#        '1,35,000', '16,00,000', '7,01,000', '2,65,000', '5,25,000',
#        '3,72,000', '6,35,000', '5,50,000', '4,85,000', '3,29,500',
#        '2,51,111', '5,69,999', '69,999', '2,99,999', '3,99,999',
#        '4,50,000', '2,70,000', '1,58,400', '1,79,000', '1,25,000',
#        '2,99,000', '1,50,000', '2,75,000', '2,85,000', '3,40,000',
#        '70,000', '2,89,999', '8,49,999', '7,49,999', '2,74,999',
#        '9,84,999', '5,99,999', '2,44,999', '4,74,999', '2,45,000',
#        '1,69,500', '3,70,000', '1,68,000', '1,45,000', '98,500',
#        '2,09,000', '1,85,000', '9,00,000', '6,99,999', '1,99,999',
#        '5,44,999', '1,99,000', '5,40,000', '49,000', '7,00,000', '55,000',
#        '8,95,000', '3,55,000', '5,65,000', '3,65,000', '40,000',
#        '4,00,000', '3,30,000', '5,80,000', '3,79,000', '2,19,000',
#        '5,19,000', '7,30,000', '20,00,000', '21,00,000', '14,00,000',
#        '3,11,000', '8,55,000', '5,35,000', '1,78,000', '3,00,000',
#        '2,55,000', '5,49,999', '3,80,000', '57,000', '4,10,000',
#        '2,25,000', '1,20,000', '59,000', '5,99,000', '6,75,000', '72,500',
#        '6,10,000', '2,30,000', '5,20,000', '5,24,999', '4,24,999',
#        '6,44,999', '5,84,999', '7,99,999', '4,44,999', '6,49,999',
#        '9,44,999', '5,74,999', '3,74,999', '1,30,000', '4,01,000',
#        '13,50,000', '1,74,999', '2,39,999', '99,999', '3,24,999',
#        '10,74,999', '11,30,000', '1,49,000', '7,70,000', '30,000',
#        '3,35,000', '3,99,000', '65,000', '1,69,999', '1,65,000',
#        '5,60,000', '9,50,000', '7,15,000', '45,000', '9,40,000',
#        '1,55,555', '15,00,000', '4,95,000', '8,00,000', '12,99,000',
#        '5,30,000', '14,99,000', '32,000', '4,05,000', '7,60,000',
#        '7,50,000', '4,19,000', '1,40,000', '15,40,000', '1,23,000',
#        '4,98,000', '4,80,000', '4,88,000', '15,25,000', '5,48,900',
#        '7,25,000', '99,000', '52,000', '28,00,000', '4,99,000',
#        '3,81,000', '2,78,000', '6,90,000', '2,60,000', '90,001',
#        '1,15,000', '15,99,000', '1,59,000', '51,999', '2,15,000',
#        '35,000', '11,50,000', '2,69,000', '60,000', '4,30,000',
#        '85,00,003', '4,01,919', '4,90,000', '4,24,000', '2,05,000',
#        '5,49,900', '3,71,500', '4,35,000', '1,89,700', '3,89,700',
#        '3,60,000', '2,95,000', '1,14,990', '10,65,000', '4,70,000',
#        '48,000', '1,88,000', '4,65,000', '1,79,999', '21,90,000',
#        '23,90,000', '10,75,000', '4,75,000', '10,25,000', '6,15,000',
#        '19,00,000', '14,90,000', '15,10,000', '18,50,000', '7,90,000',
#        '17,25,000', '12,25,000', '68,000', '9,70,000', '31,00,000',
#        '8,99,000', '88,000', '53,000', '5,68,500', '71,000', '5,90,000',
#        '7,95,000', '42,000', '1,89,000', '1,62,000', '35,999',
#        '29,00,000', '39,999', '50,500', '5,10,000', '8,60,000',
#        '5,00,001'], dtype=object)

# %%
ask_for_price_data = data2[data2.Price=="Ask For Price"]

# %%
data2 = data2[~(data2.Price=="Ask For Price")]

# %%
data2.Price = data2.Price.str.replace(",","").astype(int)

# %%
data2
# Out:
#                        name    company  year   Price    kms_driven fuel_type
# 0       Hyundai Santro Xing    Hyundai  2007   80000    45,000 kms    Petrol
# 1       Mahindra Jeep CL550   Mahindra  2006  425000        40 kms    Diesel
# 3         Hyundai Grand i10    Hyundai  2014  325000    28,000 kms    Petrol
# 4    Ford EcoSport Titanium       Ford  2014  575000    36,000 kms    Diesel
# 6                 Ford Figo       Ford  2012  175000    41,000 kms    Diesel
# ..                      ...        ...   ...     ...           ...       ...
# 886    Toyota Corolla Altis     Toyota  2009  300000  1,32,000 kms    Petrol
# 888            Tata Zest XM       Tata  2018  260000    27,000 kms    Diesel
# 889      Mahindra Quanto C8   Mahindra  2013  390000    40,000 kms    Diesel
# 890         Honda Amaze 1.2      Honda  2014  180000        Petrol       NaN
# 891      Chevrolet Sail 1.2  Chevrolet  2014  160000        Petrol       NaN
#
# [727 rows x 6 columns]

# %%
data2 = data2[data2.kms_driven!='Petrol']

# %%
data2
# Out:
#                        name   company  year   Price    kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007   80000    45,000 kms    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000        40 kms    Diesel
# 3         Hyundai Grand i10   Hyundai  2014  325000    28,000 kms    Petrol
# 4    Ford EcoSport Titanium      Ford  2014  575000    36,000 kms    Diesel
# 6                 Ford Figo      Ford  2012  175000    41,000 kms    Diesel
# ..                      ...       ...   ...     ...           ...       ...
# 883      Maruti Suzuki Ritz    Maruti  2011  270000    50,000 kms    Petrol
# 885          Tata Indica V2      Tata  2009  110000    30,000 kms    Diesel
# 886    Toyota Corolla Altis    Toyota  2009  300000  1,32,000 kms    Petrol
# 888            Tata Zest XM      Tata  2018  260000    27,000 kms    Diesel
# 889      Mahindra Quanto C8  Mahindra  2013  390000    40,000 kms    Diesel
#
# [725 rows x 6 columns]

# %%
data2.kms_driven = data2.kms_driven.str.replace(',',"").str.replace('kms','').astype(int)
# Out:
# C:\Users\Teacher\AppData\Local\Temp\ipykernel_4908\1995894490.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2.kms_driven = data2.kms_driven.str.replace(',',"").str.replace('kms','').astype(int)

# %%
data2
# Out:
#                        name   company  year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 3         Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 4    Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 6                 Ford Figo      Ford  2012  175000       41000    Diesel
# ..                      ...       ...   ...     ...         ...       ...
# 883      Maruti Suzuki Ritz    Maruti  2011  270000       50000    Petrol
# 885          Tata Indica V2      Tata  2009  110000       30000    Diesel
# 886    Toyota Corolla Altis    Toyota  2009  300000      132000    Petrol
# 888            Tata Zest XM      Tata  2018  260000       27000    Diesel
# 889      Mahindra Quanto C8  Mahindra  2013  390000       40000    Diesel
#
# [725 rows x 6 columns]

# %%
data2.fuel_type.unique()
# Out:
# array(['Petrol', 'Diesel', nan, 'LPG'], dtype=object)

# %%
data2[data2.fuel_type.isna()]
# Out:
#                name company  year   Price  kms_driven fuel_type
# 132  Toyota Corolla  Toyota  2009  275000       26000       NaN

# %%
data2.isna().sum()
# Out:
# name          0
# company       0
# year          0
# Price         0
# kms_driven    0
# fuel_type     1
# dtype: int64

# %%
data2.fuel_type.fillna(data2.fuel_type.mode()[0],inplace=True)
# Out:
# C:\Users\Teacher\AppData\Local\Temp\ipykernel_4908\814897039.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2.fuel_type.fillna(data2.fuel_type.mode()[0],inplace=True)

# %%
data2.fuel_type.unique()
# Out:
# array(['Petrol', 'Diesel', 'LPG'], dtype=object)

# %%
data2
# Out:
#                        name   company  year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 3         Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 4    Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 6                 Ford Figo      Ford  2012  175000       41000    Diesel
# ..                      ...       ...   ...     ...         ...       ...
# 883      Maruti Suzuki Ritz    Maruti  2011  270000       50000    Petrol
# 885          Tata Indica V2      Tata  2009  110000       30000    Diesel
# 886    Toyota Corolla Altis    Toyota  2009  300000      132000    Petrol
# 888            Tata Zest XM      Tata  2018  260000       27000    Diesel
# 889      Mahindra Quanto C8  Mahindra  2013  390000       40000    Diesel
#
# [725 rows x 6 columns]

# %%
ask_for_price_data.Price.replace('Ask For Price',data2.Price.median(),inplace=True)
# Out:
# C:\Users\Teacher\AppData\Local\Temp\ipykernel_4908\2232282949.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ask_for_price_data.Price.replace('Ask For Price',data2.Price.median(),inplace=True)

# %%
ask_for_price_data
# Out:
#                           name     company  year     Price    kms_driven  \
# 2           Maruti Suzuki Alto      Maruti  2018  290000.0    22,000 kms
# 5       Ford EcoSport Titanium        Ford  2015  290000.0    59,000 kms
# 69                   I want to           I  2017  290000.0           NaN
# 138         Maruti Suzuki Alto      Maruti  2018  290000.0    28,028 kms
# 295        Maruti Suzuki Swift      Maruti  2010  290000.0    52,000 kms
# 304            Tata Indica eV2        Tata  2017  290000.0    84,000 kms
# 388         Maruti Suzuki Alto      Maruti  2018  290000.0    24,000 kms
# 449          Maruti Suzuki Zen      Maruti  2011  290000.0    16,000 kms
# 503         Hyundai Xcent Base     Hyundai  2015  290000.0  1,80,000 kms
# 511            Hyundai Xcent S     Hyundai  2015  290000.0    35,000 kms
# 524          Toyota Innova 2.0      Toyota  2009  290000.0    15,574 kms
# 567             Datsun Go Plus      Datsun  2016  290000.0         5 kms
# 613         Mahindra KUV100 K8    Mahindra  2018  290000.0     7,500 kms
# 619         Maruti Suzuki Alto      Maruti  2002  290000.0    56,000 kms
# 634          Hyundai Elite i20     Hyundai  2015  290000.0    49,500 kms
# 763                 Tata Nexon        Tata  2019  290000.0         0 kms
# 822              Hyundai Venue     Hyundai  2019  290000.0     7,000 kms
# 826              Renault Lodgy     Renault  2016  290000.0    20,000 kms
# 848         Maruti Suzuki Alto      Maruti  2019  290000.0     1,500 kms
# 854  Volkswagen Vento Highline  Volkswagen  2015  290000.0    38,900 kms
# 859          Toyota Innova 2.0      Toyota  2019  290000.0     4,000 kms
# 882         Maruti Suzuki Alto      Maruti  2015  290000.0    70,000 kms
#
#     fuel_type
# 2      Petrol
# 5      Diesel
# 69        NaN
# 138    Petrol
# 295    Diesel
# 304    Diesel
# 388    Petrol
# 449    Petrol
# 503    Diesel
# 511    Petrol
# 524    Diesel
# 567    Petrol
# 613    Diesel
# 619    Petrol
# 634    Petrol
# 763    Petrol
# 822    Diesel
# 826    Diesel
# 848    Petrol
# 854    Diesel
# 859    Petrol
# 882    Petrol

# %%
data3 = pd.concat([data2,ask_for_price_data]).sample(747)

# %%
data3.reset_index(drop=True, inplace=True)

# %%
data3
# Out:
#                       name     company  year      Price kms_driven fuel_type
# 0       Hyundai i10 Sportz     Hyundai  2011   220000.0      38000    Petrol
# 1             Toyota Etios      Toyota  2011   275000.0      36000    Diesel
# 2      Hyundai Santro Xing     Hyundai  2007   135000.0      47000    Petrol
# 3    Mitsubishi Lancer 1.8  Mitsubishi  2006    85000.0      50000    Petrol
# 4              Hyundai Eon     Hyundai  2013   190000.0      25000    Petrol
# ..                     ...         ...   ...        ...        ...       ...
# 742          Hyundai Venue     Hyundai  2019   290000.0  7,000 kms    Diesel
# 743              Tata Nano        Tata  2013    60000.0       6800    Petrol
# 744           BMW 7 Series         BMW  2009  1600000.0      35000    Petrol
# 745    Maruti Suzuki Swift      Maruti  2015   475000.0      43000    Diesel
# 746         Tata Indigo CS        Tata  2017   270000.0      50000    Diesel
#
# [747 rows x 6 columns]

# %%
data3.fuel_type.value_counts()
# Out:
# fuel_type
# Petrol    403
# Diesel    341
# LPG         2
# Name: count, dtype: int64

# %%
data3[data3.company=='Maruti']['Price'].mean()
# Out:
# np.float64(271795.2047619048)

# %%
data3[(data3.company=='Maruti') & (data3.fuel_type=='Petrol')]['Price'].mean()
# Out:
# np.float64(226423.03289473685)
