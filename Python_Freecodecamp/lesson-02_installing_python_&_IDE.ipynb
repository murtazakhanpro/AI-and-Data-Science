# %% [markdown]
# ### Istalling python
# # head over to https://www.python.org/downloads
# and install the latest and most statble version
# # for IDE (intergraded development Enviroment)
# we are going to be using Jupyter Notebook, Vs Code and pycharm
