# %% [markdown]
# ## Introduction to python
# python is the most famous programming language among all
# it has very easy learning curve compare to different programming langues,
# it's is used in almost every kind of development beucase of it's wast majority of libraries
# we are going to using python for Ai and DataScience
