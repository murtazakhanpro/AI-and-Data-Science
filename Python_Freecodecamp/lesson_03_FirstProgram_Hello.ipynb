# %% [markdown]
# ## we are going to write our first program and print it to the terminal python is very easy you just write likke english like speaking to someone and programms

# %% [markdown]
# print("Hello World")

# %%
print("Hello world")
# Out:
# Hello world
