# %%
class person:
    def __init__(self,gender,age,name,height,weight,blood_gp):
        self.gender = gender
        self.name = name
        self.age = age
        self.height = height
        self.weight = weight
        self.blood_op = blood_gp
    
    def eat(self):
        print(f"")
