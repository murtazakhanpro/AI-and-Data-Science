# %% [markdown]
# # first Understand in the simplest way

# %% [markdown]
# ##### -Variable Box

# %%
name1 = 'Murtaza Ali Khan'

name1
# Out:
# 'Murtaza Ali Khan'

# %% [markdown]
# #### Expression = Calculation / Work

# %%
total = 5 + 3

# %%
total
# Out:
# 8

# %%
a = 10
b = 20
c = 30
print(a+b)
a+c
b+c
c+a
# Out:
# 30
# 40

# %%
name = "Murtaza"
city = "Karachi"
course = "AI & DS"

print("My name is " + name)
print("I live in " + city)
print("I am learning " + course)
# Out:
# My name is Murtaza
# I live in Karachi
# I am learning AI & DS

# %%
name.capitalize()
# Out:
# 'Murtaza ali khan'

# %%
name.upper()
# Out:
# 'MURTAZA'

# %%
print(name.upper())
# Out:
# MURTAZA

# %%
position = name.find("A")

# %%
print(position)
# Out:
# -1

# %%
colors = ["red", "orange", "yellow", "green", "blue", "indigo", "violet"]

for index, color in enumerate(colors):
    print(index, color)
# Out:
# 0 red
# 1 orange
# 2 yellow
# 3 green
# 4 blue
# 5 indigo
# 6 violet

# %%
for index , color in enumerate(colors):
    print(index, color)
# Out:
# 0 red
# 1 orange
# 2 yellow
# 3 green
# 4 blue
# 5 indigo
# 6 violet
