# %%
import bank

# %%
bank.open_account(4563467, 40000)
# Out:
# Enter account title:  nasir hussain
# Thank you for opening account with us!
# {'cnic': 4563467,
#  'balance': 40000,
#  'account_title': 'nasir hussain',
#  'pin': 1687,
#  'account_number': 8711989}

# %%
bank.open_account(654322,30000)
# Out:
# Enter account title:  rehan khan
# Thank you for opening account with us!
# {'cnic': 654322,
#  'balance': 30000,
#  'account_title': 'rehan khan',
#  'pin': 9239,
#  'account_number': 7864666}

# %%
bank.bank_all_accounts
# Out:
# [{'cnic': 4563467,
#   'balance': 40000,
#   'account_title': 'nasir hussain',
#   'pin': 1687,
#   'account_number': 8711989},
#  {'cnic': 654322,
#   'balance': 30000,
#   'account_title': 'rehan khan',
#   'pin': 9239,
#   'account_number': 7864666}]
