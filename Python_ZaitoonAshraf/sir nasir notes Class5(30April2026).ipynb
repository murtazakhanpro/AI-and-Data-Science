# %% [markdown]
# We have to buy some thing. (Laptop)
#    - HP
#    - Corei7
#    - SSD 1TB
#    - Ram 16GB
#    - Generation 11th

# %%
brand = input("which brand is  avaialble  : ").lower()
if brand=='hp':
    processor = input("which core avaialble :").lower()
    if processor=='corei7':
        ssd  = input("SSD kitni miljaegi?         :").lower()
        if ssd=='1tb':
            ram  = input("RAM kitni milegi?           :").lower()
            if ram=='16gb':
                generation = input("Generation kia hogi?").lower()
                if generation=='11th':
                    print("Thk hy ye wala system dedo!")
                else:
                    print("Mujher to 11th Gen chahye thi,Thanks")
            else:
                print("Mujher to 16GB ram chahye thi,Thanks")            
        else:
            print("Mujher to 1tb chahye thi,Thanks")
    else:
        
        print("Mujher to Corei7 chahye tha,Thanks")
else:
    print("Ok mujhe to HP he chahye.Thanks")
# Out:
# which brand is  avaialble  :  hp
# which core avaialble : no
# Mujher to Corei7 chahye tha,Thanks

# %%
python = int(input("Enterpython marks"))
if python>=70:
    science= int(input("Enter sciencemarks"))
    if science>=70:
        maths= int(input("Enter mathsmarks"))
        if maths>=70:
            computer= int(input("Entercomputer marks"))
            if computer>=70:
                english= int(input("Enter englishmarks"))
                if english>=70:
                    result = 'PASS'
                else:
                    result ="Fail in English"
            else:
                result ="Fail in Computer"
        else:
            result ="Fail in Maths"        
    else:
        result ="Fail in Science"
else:
    result='Fail in Python'
result
# Out:
# Enterpython marks 52
# 'Fail in Python'

# %%
if (maths>=70) and (python>=70) and (science>=70) and (computer>=70) and (english>=70):
    result = 'PASS'
else:
    result='Fail'
result
# Out:
# 'Fail'

# %% [markdown]
# # Python Data Structures:
#   - String    " "
#   - List      []
#   - Tuple     ( )
#   - Dictionary {k:v}
#   - Set        {}

# %% [markdown]
# # List:
#    - Python colection
#    - declare []
#    - can hold many value of different and same data type
#    - mutable
#    - iterable

# %%
list_a = []

# %%
print(type(list_a))
# Out:
# <class 'list'>

# %%
len(list_a)
# Out:
# 0

# %%
list_a = ['asad', 23, True, 34.6]

# %%
len(list_a)
# Out:
# 4

# %%
#             0         1         2         3         4             5       6       7
students = ['Keshaf', 'Asif', 'Ghaffar', 'Najam', 'SalmanShah', 'Sameer', 'Anas', 'IK']
#             -8         -7      -6        -5        -4            -3       -2      -1

# %%
len(students)
# Out:
# 8

# %%
print(students)
# Out:
# ['Keshaf', 'Asif', 'Ghaffar', 'Najam', 'SalmanShah', 'Sameer', 'Anas', 'IK']

# %% [markdown]
# ### Accessing members using index

# %%
students[-5]
# Out:
# 'Najam'

# %%
students[4]
# Out:
# 'SalmanShah'

# %%
student_name = 'SalmanShah'

# %%
student_name[5]
# Out:
# 'n'

# %%
students[7]
# Out:
# 'IK'

# %%
students[11]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 students[11]
#
# IndexError: list index out of range

# %% [markdown]
# #### Adding more members to an existing list
#    - append("member") add 1 member at the last index
#    - insert(index, member) add 1 memebr at given index
#    -  extend (list ko extend karta hai rather than nest)

# %%
students.append("Asim Kamal")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 students.append("Asim Kamal")
#
# NameError: name 'students' is not defined

# %%
students
# Out:
# ['Keshaf',
#  'Asif',
#  'Ghaffar',
#  'Najam',
#  'SalmanShah',
#  'Sameer',
#  'Anas',
#  'IK',
#  'Asim Kamal']

# %%
students.insert(5,'Usman')

# %%
students
# Out:
# ['Keshaf',
#  'Asif',
#  'Ghaffar',
#  'Najam',
#  'SalmanShah',
#  'Usman',
#  'Sameer',
#  'Anas',
#  'IK',
#  'Asim Kamal']

# %%
students.insert(-5,'Waqas')

# %%
students
# Out:
# ['Keshaf',
#  'Asif',
#  'Ghaffar',
#  'Najam',
#  'SalmanShah',
#  'Waqas',
#  'Usman',
#  'Sameer',
#  'Anas',
#  'IK',
#  'Asim Kamal']

# %%
students.insert(45,'Waqas')

# %%
students
# Out:
# ['Keshaf',
#  'Asif',
#  'Ghaffar',
#  'Najam',
#  'SalmanShah',
#  'Waqas',
#  'Usman',
#  'Sameer',
#  'Anas',
#  'IK',
#  'Asim Kamal',
#  'Waqas']

# %% [markdown]
# ### Delete A memebr from a list
#    - del
#    - pop()
#    - remove()
#     - clear()

# %%
del students[6]

# %%
students
# Out:
# ['Keshaf',
#  'Asif',
#  'Ghaffar',
#  'Najam',
#  'SalmanShah',
#  'Waqas',
#  'Sameer',
#  'Anas',
#  'IK',
#  'Asim Kamal',
#  'Waqas']

# %%
students.pop() # last index deltes but return the value
# Out:
# 'Waqas'

# %%
teacher = []

# %%
teacher.append(students.pop())

# %%
teacher
# Out:
# ['Asim Kamal']

# %%
students
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 students
#
# NameError: name 'students' is not defined

# %%
students.pop(5)
# Out:
# 'Waqas'

# %%
students.remove('SalmanShah')

# %%
students
# Out:
# ['Keshaf', 'Asif', 'Ghaffar', 'Najam', 'Sameer', 'Anas', 'IK']

# %%
popped_value = students.pop()

# %%
students
# Out:
# ['Keshaf', 'Asif', 'Ghaffar', 'Najam', 'Sameer', 'Anas']

# %%
popped_value
# Out:
# 'IK'

# %%
students = ["kamran" , "irfan" , "nasir" , "zeeshan"]

# %%
students
# Out:
# ['irfan', 'kamran', 'nasir', 'zeeshan']

# %%
students.sort()

# %% [markdown]
# # dictionary
#     - declear {k:v} key or value mila kar dictionary banta ha
#     - mutable
#     - iterable
#     - no index
#     - access via keys

# %%
student = ['asad' , 'wali' '34' , '43', 'kamran' , 'karachi']

# %%
student
# Out:
# ['asad', 'wali34', '43', 'kamran', 'karachi']

# %%
type(student)
# Out:
# list

# %% [markdown]
# ### dictionary delcearation

# %%
student_dic = {'name': 'asad' , 'fname':'wali' , 'roll':'23', 'age':'45', 'course':'python', 'city':'karachi'}

# %%
type(student_dic)
# Out:
# dict

# %%
student_dic['fname']
# Out:
# 'wali'

# %%
student_dic
# Out:
# {'name': 'asad', 'fname': 'wali'}

# %% [markdown]
# ##### deleting a item rom a dictionary
#     - pop()
#     - del
#     - clear()
#     - pop_item()
#     -

# %%
del student_dic['fname']

# %%
student_dic
# Out:
# {'name': 'asad'}

# %%
student_dic.popitem()
# Out:
# ('city', 'karachi')

# %%
student_dic.items()
# Out:
# dict_items([('name', 'asad'), ('fname', 'wali'), ('roll', '23'), ('age', '45'), ('course', 'python')])

# %%
student_dic.get('roll')
# Out:
#   Cell In[30], line 1
#     student_dic.get('roll
#                     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
student_dic
# Out:
# {'name': 'asad',
#  'fname': 'wali',
#  'roll': '23',
#  'age': '45',
#  'course': 'python'}

# %%
data = {'email':'abc@gmail.com' , 'address' : '123df'}

# %%
result ={'roll' :[1,2,3,4,5,6,7,8,9], 
         'name':['Keshaf', 'Asif', 'Ghaffar', 'Najam', 'Sameer', 'Anas'] , 
         'python':[78,79,80,81,82,84,54] , 
         'javascript': [78,79,80,81,82,84,54],
         'ml ':[78,79,80,81,82,84,54]}

# %% [markdown]
# # Dictionary in a dictionary

# %%
stores = {'baloch':{'laptop':200000, 'mouse':2000, 'ssd':60000}
          # {'bahadurabad':{'laptop'}}
         }

# %% [markdown]
# # tuple
#
#     - immutable
#     - tuple is default type of collection
#     - ()

# %% [markdown]
# # set
#     - declear {2,3,4,5,6}

# %%
aset = {1,2,3,4,5,6,7,8,9}

# %%
aset.
