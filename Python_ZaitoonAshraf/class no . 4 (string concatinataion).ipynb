# %% [markdown]
# # Class 4 28-04-2026|
#
#     - string concatination

# %%
first_name = "Ahmed"
middle_name = "Ali"
Last_name = "Jami"

# %%
first_name+middle_name+Last_name
# Out:
# 'AhmedAliJami'

# %%
first_name+" "+middle_name+" "+Last_name+" "
# Out:
# 'Ahmed Ali Jami '

# %% [markdown]
# # F_String
#
#     - f'''  yeh humara concatenation wala kam asan kar deta hai

# %%
print(f'''{first_name} {middle_name} {Last_name}''') #multi-line string
# Out:
# Ahmed Ali Jami

# %%
print(f''' 
My first is   {first_name}
My middle is  {middle_name}
My Last is    {Last_name}



''')
# Out:
#
# My first is   Ahmed
# My middle is  Ali
# My Last is    Jami

# %%
age = int(input("please enter your age"))
# Out:
# please enter your age 23

# %%
print age
# Out:
#   Cell In[9], line 1
#     print age
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print(age)
# Out:
# 23

# %%
print(f''' 
My first is   {first_name}
My middle is  {middle_name}
My Last is    {Last_name}
My age is {age}


''')
# Out:
#
# My first is   Ahmed
# My middle is  Ali
# My Last is    Jami
# My age is 23

# %% [markdown]
# # String is a package
#     - string is a python collection. (collection is group of to many things)
#     - String is immutable. (once decleared and initialised can not be changed)
#     - can be indexed and iterated (looped)

# %%
course = "artificial intelligence and data science"

# %%
print(type(course))
# Out:
# <class 'str'>

# %%
help(course)
# Out:
# No Python documentation found for 'artificial intelligence and data science'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.

# %%
course.upper() # yeh sirf yeh baata hai k sirf upper karne pr is tarhan dikhay ga (memory change nhi hue ha)
# Out:
# 'ARTIFICIAL INTELLIGENCE AND DATA SCIENCE'

# %%
# agar koi function lagany pr terminal pr view nhi ata to iska matlab memory main update nhi hue hai

# %%
id(course
  )
# Out:
# 1483576345968

# %%
course.lower()
# Out:
# 'artificial intelligence and data science'

# %% [markdown]
# # python conditional statements / clauses
#     - if
#     - if else
#     - if elif else

# %%
age
# Out:
# 23

# %%
age = int(input("Enter your age here!"))
if age>=60:
    print("senior citizen")
    print("No que")
    print("life time") #cnic
    print("seat reserved")
    print("Half Ticket")
# Out:
# Enter your age here! 70
# senior citizen
# No que
# life time
# seat reserved
# Half Ticket

# %%
age = int(input("Enter your age here!"))
if age>=60:
    print("senior citizen")
    print("No que")
    print("life time") #cnic
    print("seat reserved")
    print("Half Ticket")
else:
    print("No senior citizen")
    print("Yes que")
    print("No life time") #cnic
    print("No seat reserved")
    print("Full-Half Ticket")
# Out:
# Enter your age here! 60
# senior citizen
# No que
# life time
# seat reserved
# Half Ticket

# %%
temp = float(input("What is the temperature today?"))
if temp>=35:
    print("It's Hot outside")
else:
    print("It's normal outside")
# Out:
# What is the temperature today? 45
# It's Hot outside

# %%
price = int(input("please enter the price of the watch"))
if price<2000:
    print("tum sy na ho paega")
else:
    print("tum to ameer ho")
# Out:
# please enter the price of the watch 3000
# tum to ameer ho

# %%
marks = int(input("enter marks in python"))

if marks >=70:
    print('pass')
else:
    print("fail")
# Out:
# enter marks in python 78
# pass

# %%
salary = int(input("Enter your salary"))
if salary >= 50000:
    tax = salary*.10
    print(f'''
    Salary Account:
    Your salary is   {salary}
    Your Tax is      {tax}
    =========================
    Net Salary month {salary-tax}
    ''')
# Out:
# Enter your salary 50000
#     Salary Account:
#     Your salary is   50000
#     Your Tax is      5000.0
# ...
#     Net Salary month 45000.0

# %%
salary = int(input("Enter your salary"))
net_salary = salary-tax

if salary <= 500000:
    tax = salary*.30
elif salary <= 400000:   
    tax = salary*0.25
elif salary <= 300000:   
    tax = salary*0.20 
elif salary <= 200000:   
    tax = salary*0.15 
elif salary <= 100000:   
    tax = salary*0.10   
elif salary <= 50000: 
    tax = salary*0 


else:
    tax=salary*.30


print(f'''
    Salary Account:
    Your salary is   {salary}
    Your Tax is      {tax}
    =========================
    Net Salary month {net_salary}
    ''')
# Out:
# Enter your salary 40000
#     Salary Account:
#     Your salary is   40000
#     Your Tax is      12000.0
# ...
#     Net Salary month 31000.0

# %%
salary = int(input("Enter your salary"))
# maths = int(input(:"Enter your maths marks"))
# science = int(input(:"Enter your science marks"))
# english = int(input(:"Enter your english marks"))
# python = int(input(:"Enter your python marks"))
# chemistry = int(input(:"Enter your chemistry marks"))
net_salary = salary-tax

if salary <= 500000:
    tax = salary*.30
elif salary <= 400000:   
    tax = salary*0.25
elif salary <= 300000:   
    tax = salary*0.20 
elif salary <= 200000:   
    tax = salary*0.15 
elif salary <= 100000:   
    tax = salary*0.10   
elif salary <= 50000: 
    tax = salary*0 


else:
    tax=salary*.30


print(f'''
    Salary Account:
    Your salary is   {salary}
    Your Tax is      {tax}
    =========================
    Net Salary month {net_salary}
    ''')
# Out:
# Enter your salary 500000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 7
#       1 salary = int(input("Enter your salary"))
#       2 # maths = int(input(:"Enter your maths marks"))
#       3 # science = int(input(:"Enter your science marks"))
#       4 # english = int(input(:"Enter your english marks"))
#       5 # python = int(input(:"Enter your python marks"))
#       6 # chemistry = int(input(:"Enter your chemistry marks"))
# ----> 7 net_salary = salary-tax
#       9 if salary <= 500000:
#      10     tax = salary*.30
#
# NameError: name 'tax' is not defined

# %% [markdown]
# # Nested Blocks, (condition k ander conditions)

# %%
card = input("Card dekhaooooo! ")
if card == 'yes':
    fee = input("Fee paid hai apki ! ")
    if fee == 'yes':
        attend = input("koi chuti to nhi apne ")
        if attend == "no":
            print("Apki class 8pm pr start hogi")
            assignment = input("Assignment kr k laye ho ya nhi ")
            if assignment == 'yes':
                print("Good Job!")
            else:
                print("Ap Aj class nhi ly sakte phely apna Home Assignment Complete karo")
        else:
            print("Apko warning di ja rahi hai next time khayal rakhna")
    else:
        print("Phely Fee Pay Karo!")
else:
    print("Ghar Jao")
# Out:
# Card dekhaooooo!  yes
# Fee paid hai apki !  yes
# koi chuti to nhi apne  no
# Apki class 8pm pr start hogi
# Assignment kr k laye ho ya nhi  yes
# Good Job!
