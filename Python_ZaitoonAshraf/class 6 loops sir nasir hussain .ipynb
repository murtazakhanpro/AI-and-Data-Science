# %% [markdown]
# # loops
#     - For in : required collection
#     - While  : True (condition chahiye hoti hai isko)

# %%
for a in range(10):
    print('salam')
# Out:
# salam
# salam
# salam
# salam
# salam
# salam
# salam
# salam
# salam
# salam

# %%
for a in range(10,0-2):  # (start, end, step)
    print(a,'salam')

# %%
for a in range(10):
    if a==5:
        break
    print(a, a**2)
# Out:
# 0 0
# 1 1
# 2 4
# 3 9
# 4 16

# %% [markdown]
# # While loop
