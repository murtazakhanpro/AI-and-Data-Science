# %% [markdown]
# # Error handleling in python jo eik bohat he important topics hain

# %%
# example
int(apple)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # example
# ----> 2 int(apple)
#
# NameError: name 'apple' is not defined

# %% [markdown]
# # ab is tarhan k error ko handle karna hoga so that program errors na through kare

# %%
num1 = int(input("Please enter a number"))
num2 = int(input("Please enter a number"))
print(num1/num2)
# Out:
# Please enter a number 33
# Please enter a number apple
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 num1 = int(input("Please enter a number"))
# ----> 2 num2 = int(input("Please enter a number"))
#       3 print(num1/num2)
#
# ValueError: invalid literal for int() with base 10: 'apple'

# %%
num1 = int(input("Please enter a number"))
num2 = int(input("Please enter a number"))
try:
    print(num1/num2)
except ZeroDivisionError:
    print("You can not divide a number by 0")
# Out:
# Please enter a number 33
# Please enter a number mu
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 num1 = int(input("Please enter a number"))
# ----> 2 num2 = int(input("Please enter a number"))
#       3 try:
#       4     print(num1/num2)
#
# ValueError: invalid literal for int() with base 10: 'mu'

# %%
lst = [1,2,3,4,5]
try:
    num1 = int(input("Please enter a number"))
    num2 = int(input("Please enter a number"))
    res = num1/num2

except:
    print('Error aya tha mene pakar lia hy!')
# Out:
# Please enter a number 33
# Please enter a number 33.3.
# Error aya tha mene pakar lia hy!
