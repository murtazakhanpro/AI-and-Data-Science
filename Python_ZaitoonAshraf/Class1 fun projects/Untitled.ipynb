# %% [markdown]
# # Fun Mini Project (Python)

# %%
name = input("please enter your name:")
age = int(input("please enter your age:"))
fav_num = int(input("please enter your favorite number:"))
ao_num = int(input("please enter you second numeber:"))

print("hello", name , "you are", age , "year old your favorite number is" ,fav_num)
# Out:
# please enter your name: mujtaba
# please enter your age: 15
# please enter your favorite number: 23
# please enter you second numeber: 33
# hello mujtaba you are 15 year old your favorite number is 23
