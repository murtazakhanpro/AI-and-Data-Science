# %% [markdown]
# # goal:
#     - take input from user
#     - print the data

# %%
name = input("Please Enter Your Name: ")
age = input("Please Enter your age: ")
city = input("Please enter your city: ")
favorite_color = input("Please enter your favorite color: ")

  
# Use lowercase 'print' and the variable name 'city'
print(f"My name is {name}. i'm {age}. i live in {city}. i like {favorite_color} color")
# Out:
# Please Enter Your Name:  Murtaza
# Please Enter your age:  28
# Please enter your city:  Karachi
# Please enter your favorite color:  WHite
# My name is Murtaza. i'm 28. i live in Karachi. i like WHite color
