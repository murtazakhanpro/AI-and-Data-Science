# %%
name = "Murtaza Ali"
age  = 28
city = "karachi"

print('This Is my Introduction')
print('My name is' , name)
print("i am", age ,"year old")
print("i live in" , city , "of pakistan")
# Out:
# This Is my Introduction
# My name is MUrtaza Ali
# i am 28 year old
# i live in karachi of pakistan
