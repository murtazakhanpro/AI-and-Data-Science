# %% [markdown]
# # Logical Operators
#     - Not
#     - OR
#     - AND

# %%
12 > 10 or (day == 'sunday')
# Out:
# True

# %%
day = "sunday"

12 > 10 or (day == 'sunday')
# Out:
# True

# %% [raw]
# ##### or ko sirf eik TRUE chahiye hota hai true hone k liye
# cond 1  or  cond2  result
# True        True   True
# True        False  True
# Flase       True   True
# False       False  False
#
# # AND ko sirf eik False chahiye hota hai False hone k liye
# cond 1  or  cond2  result
# True        True   True
# True        False  False
# Flase       True   False
# False       False  False
#
#
# NOT:
# 12 > 10 >>>>>> True
# not(12 > 10) >>> False

# %%
age = 25
gender = 'male'

# %%
age > 25 or gender == 'male'
# Out:
# True

# %%
"a" not in "apple"
# Out:
# False

# %% [markdown]
# ##### solving python expression (solving ambiguity)
#     - pamdas , bodmas

# %%
x = 10.0
y = (x < 100.0) and isinstance(x, float)

# %%
print(y)
# Out:
# True

# %%
a = 100
b = 200
c = 1
a and b and c
# Out:
# 1

# %%
x = -100
from math import sqrt
x > 0 and sqrt(x)
# Out:
# False

# %%
num1 = 1
num2 = 1
