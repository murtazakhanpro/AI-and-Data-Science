# %% [markdown]
# # Logical Operators:
#     -  Not
#     -  OR
#     -  AND

# %% [raw]
# OR:
# exp1  OR exp2      Result
# True      True       True
# True      False      True
# False     True       True
# False     False      False
#
# NOTE: OR needs ONE True to mae expression TRUE
#
# AND
# exp1  AND exp2      Result
# True      True       True
# True      False      False
# False     True       False
# False     False      False
#
# NOTE: AND needs ONE False to make expression False
#
# NOT:
# 12>10 >>>> True
# not(12>10) >>> False

# %%
age = 25 
gender  = 'male'

# %%
age>25 or gender=='male'
# False   or       True
# Out:
# True

# %% [markdown]
# ##### Solving python expression (soving ambiguity)
#    - pamdas , bodmas

# %%
1.1 + 2.2 == 3.3
# Out:
# False

# %%
1.1 + 2.2
# Out:
# 3.3000000000000003

# %%
10/3 == 3.33
# Out:
# False

# %%
10/3
# Out:
# 3.3333333333333335

# %%
num = 4.5
type(num)
# Out:
# float

# %%
isinstance(num,int)
# Out:
# False

# %%
12>10
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool('apple')
# Out:
# True

# %%
bool("")
# Out:
# False

# %%
bool(1234)
# Out:
# True

# %%
bool([])
# Out:
# False

# %%
bool(0.000012)
# Out:
# True

# %%
None

# %%
bool(None)
# Out:
# False

# %%
a=100
b=200
 
a and b
# Out:
# 0

# %%
c=0
a=100
b=200

a and b and c
# Out:
# 0

# %%
c and b and a
# Out:
# 0

# %%
c=300
a=100
b=200

(a>b) and (b<c )and (c>a)
# Out:
# False

# %%
c=""
a=100
b=200

c and b and a
# Out:
# ''

# %%
x = -100
from math import sqrt
x < 0 and sqrt(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 3
#       1 x = -100
#       2 from math import sqrt
# ----> 3 x < 0 and sqrt(x)
#
# ValueError: math domain error

# %%
a = 10

# %%
a + 2
# Out:
# 12

# %%
a = a+2

# %%
a
# Out:
# 12

# %%
a+=2
a
# Out:
# 14

# %%
a*=2
a
# Out:
# 28

# %%
a
# Out:
# 28

# %% [markdown]
# # Bitwise operator

# %%
12 & 5  # and
# Out:
# 4

# %%
12|5  # or
# Out:
# 13

# %%
bin(12)
# Out:
# '0b1100'

# %%
bin(5)
# Out:
# '0b101'

# %%
0b1100 | 0b101
# Out:
# 13

# %% [markdown]
# # User_Input

# %%
age = input("Enter your age: ")
age
# Out:
# Enter your age:  23
# '23'

# %%
print("eh")

# %%
age + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 age + 1
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# # Type Casting

# %%
int(34.5)
# Out:
# 34

# %%
float(34)
# Out:
# 34.0

# %%
int("23")
# Out:
# 23

# %%
int("23-1")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 int("23-1")
#
# ValueError: invalid literal for int() with base 10: '23-1'

# %%
int("34.7")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 int("34.7")
#
# ValueError: invalid literal for int() with base 10: '34.7'

# %%
int(float("34.7"))
# Out:
# 34

# %%
age = int(input("Enter your age: "))
int(age)
# Out:
# Enter your age:  45
# 45

# %%
type(age)
# Out:
# int

# %%
weight = float(input("Enter your weight: "))
weight
# Out:
# Enter your weight:  67
# 67.0

# %% [markdown]
# # String Concatenation(Joining)

# %%
first_name = "Ahmed"
middle_name = "Ali"
last_name = "Jami"
age = 28

# %%
print(first_name)
# Out:
# Ahmed

# %%
first_name + middle_name + last_name
# Out:
# 'AhmedAliJami'

# %%
first_name + isinstance(age , str)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 first_name + isinstance(age , str)
#
# TypeError: can only concatenate str (not "bool") to str
