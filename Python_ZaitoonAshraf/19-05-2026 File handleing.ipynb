# %% [markdown]
# # File Handling file I/O Streaming

# %%
lst = [1,2,3,4,5,6,7,8,9]

# %% [markdown]
# ### right now hamara data temporary files ko ram main store kar raha hai, aur jab hum terminal ko re-start krte hain to yeh sari memory ko reset kr deta hai, iska haal yeh hai k hum isme database connect kr dete hain

# %% [markdown]
# # is kam k lea hum kuch functions istamal krte hain
# - open()

# %%
file = open('test.txt')

# %%
file.readlines()
# Out:
# ['Hello World \n',
#  "i'm murtaza ali a student in saylani MIT\n",
#  'learning from my mentor Sir Nasir Hussain\n']

# %%
file.readline()
# Out:
# ''

# %%
file.read()
# Out:
# ''

# %% [markdown]
# #### kyun k file agay pohanch gaye hai islea ab isko open nhi kare ga iska eik hal yeh ha k hum isko seek command laga kr peechay ja sakty hain

# %%
file.close() # eik file ko open krne k baad close bi krte hain

# %% [markdown]
# # Context Manager
# - agar ap file close kran bhool jain to phir hum contex manger use krte hain

# %%
# example
with open ('test.txt') as f:
    content = f.read()

# %%
content
# Out:
# "Hello World \ni'm murtaza ali a student in saylani MIT\nlearning from my mentor Sir Nasir Hussain\n"

# %%
with open('my_file.txt', 'w') as f:
    f.write("heelo hello")

# %% [markdown]
# ### is me bhi hamray pass 3 method hoty hain
# - read
# - write
# - append
# - w+ create file
# -

# %% [markdown]
# # it's best to use pandas it's instead of build in file handling

# %% [markdown]
# # Exceptional hHandling / Error Handling

# %% [raw]
# Kuch errors ahsay hotey hain jo runtime pr nhi atay os surat main hum khud say error design krte hain
