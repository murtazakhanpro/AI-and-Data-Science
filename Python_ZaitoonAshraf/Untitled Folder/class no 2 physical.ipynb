# %% [markdown]
# ##### jab bhi humain koi text likhna hoga to wo  hamesha quotation " " laga kr likhain gy

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Today is our first class")
# Out:
# Today is our first class

# %%
print('I am a single qoute text')
# Out:
# I am a single qoute text

# %%
print("I am a double qoute text")
# Out:
# I am a double qoute text

# %%
print(''' Iam a single triple qoute''')
# Out:
#  Iam a single triple qoute

# %%
print("""I am a double triple qoute""")
# Out:
# I am a double triple qoute

# %% [markdown]
# # What is the difference

# %% [markdown]
# ##### What is the difference
#     - single / Double qoutes are one-liners
#     - Triple Qoutes are multi-Liner

# %% [raw]
# I am a python learner.
#
#         Are you enjoying python programming?

# %%
Print("I am a python learner.

        Are you enjoying python programming?")
# Out:
#   Cell In[8], line 1
#     Print("I am a python learner.
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("""I am a python learner.

        Are you enjoying python programming?""")
# Out:
# I am a python learner.
#
#         Are you enjoying python programming?

# %% [markdown]
# # Today topic's:
#     - print
#     - Oerators
#     - Data Types

# %% [markdown]
# # Data Types
#         theses are premitive type
#     - Text  :  String (str) "String" , "23"
#     - Number:
#         - whole : Integers (int)   whole number (0,1,2,3..........infnity)
#         - Decimals: Floats (float) decimal numbers (0.1,0.2,1.0,1.2........infinity)
#
#     Boolean      : Boolean (bool) True / False

# %%
print(type("hello"))
# Out:
# <class 'str'>

# %%
print(type(123))
# Out:
# <class 'int'>

# %%
print(type(True))
# Out:
# <class 'bool'>

# %%
print(type(False))
# Out:
# <class 'bool'>

# %%
python is case sensitive language

# %% [markdown]
# # Operators
#     - Artimatic Operators
#     - + , - , *, / ,  // , % , **
#     - Comparision Operators
#         - >  (Greater Than)
#         - <  (Less Than)
#         - <= (Less Than Equal to)
#         - >= (Greater than Equal to)
#         - != (Not Equal to)
#         - == (Equal to)
#
#     - Assignment Operators (=)
#     - Membership Operator  (in)
#     - Idnetity Operators   (is)
#
#     - Logical Operators
#         - not
#         - or
#         - and
#         - xor
#
#     - Bitwise operator

# %% [markdown]
# # Aritimatic Operators

# %%
12 + 4
# Out:
# 16

# %%
12-4
# Out:
# 8

# %%
12*4
# Out:
# 48

# %% [markdown]
# ##### yeh wala operator decimal ma answer deta ha

# %%
12 / 4
# Out:
# 3.0

# %% [markdown]
# ##### yeh wal simple devide krta ha

# %%
12 // 5
# Out:
# 2

# %%
100 / 15
# Out:
# 6.666666666666667

# %% [markdown]
# ##### Modulas Operator (reminader ma answer la kr deta ha)

# %%
100 % 15
# Out:
# 10

# %% [markdown]
# ##### Comparision Operator results in Boolean (yeh hamain true ya falst ma answer deta ha)

# %%
12 <10
# Out:
# False

# %%
12>10
# Out:
# True

# %%
12<=10
# Out:
# False

# %%
12>=10
# Out:
# True

# %%
12==10
# Out:
# False

# %%
12 ==4
12 + 5
12 - 5
# Out:
# 7

# %% [markdown]
# ##### Jupyter notebook ma eik function jo cheez bhi ksis cell main hoti hai uski sabse last wali by default print hojati ha

# %% [markdown]
# # Variables:
#     - Variables are containers that holds values (also know as Identifers)
#     -

# %%
name = ' syed usman shah' #(A string value assign to variable)
id(name)
# Out:
# 1753086824304

# %% [markdown]
# name

# %%
print(name)
# Out:
#  syed usman shah

# %%
name1 = 'atif bajwa'

# %%
print(name)
# Out:
# atif bajwa

# %%
print( name, name1)
# Out:
# atif bajwa atif bajwa

# %%
name
# Out:
# 'atif bajwa'

# %%
id(name)
# Out:
# 1753087432496

# %%
age = 23

# %%
age
# Out:
# 23

# %%
age = 40

# %%
age
# Out:
# 40

# %%
trainer = 'Usaman'

# %%
print(trainer)
# Out:
# Usaman

# %% [markdown]
# # some things to consider when naming variable

# %%
weight_kg = 56

# %% [raw]
# koi ahsa nam nhi rakh sakte jo reserve python ka keyword ho
#     -List of Reserve Word

# %% [markdown]
# ![image.png](attachment:d04e27f1-571e-489c-869e-3b58978780a2.png)

# %% [markdown]
# # Identiy operator (maloom)

# %%
"a" in "pakistan"
# Out:
# True

# %%
name = "kamran shah"

# %%
id(name)
# Out:
# 1753087614192

# %%
student_name = name

# %%
print(name)
# Out:
# kamran shah

# %%
id(student_name)
# Out:
# 1753087614192

# %%
new_student = "kamran shah"

# %%
id(new_student)
# Out:
# 1753100969840

# %%
num1 = 20
num2 = 5
result = num1 / num2

# %%
print(result)
# Out:
# 4.0

# %%
print(num1 / num2)
# Out:
# 4.0

# %%
num3= '23'

# %%
print(type(num3))
# Out:
# <class 'str'>
