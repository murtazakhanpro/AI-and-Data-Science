# %% [markdown]
# # Today's Topics
#     = print
#     = operators
#     = data type

# %% [markdown]
# ### Print
#     - print is a python build in fuction, that prints any valid value given to it. ( value>>argument)
#     - print can print any number of values comma seperated
#     - print can take no value
# ### Value
#     - value can be of different types:
#         - nunber
#             - whole number (integers): int
#             - decimal numbers (float): float
#         - text
#             - strings: anything written in qoutes. {"A", 'A', """A """, ''' A'''}

# %%
Print("hello")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 Print("hello")
#
# NameError: name 'Print' is not defined

# %%
print("I am the first argument to print function")
# Out:
# I am the first argument to print function

# %%
print("i am double qouted single line string")
print('i am single qouted single line string')

print ("""I am double tripple qouted multiline string""")
print ('''I am single tripple qouted multiline string''')
# Out:
# i am double qouted single line string
# i am single qouted single line string
# I am double tripple qouted multiline string
# I am single tripple qouted multiline string

# %%
print("I will be there at
      9:pm")
# Out:
#   Cell In[10], line 1
#     print("I will be there at
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('I will be there at
      9:5pm')
# Out:
#   Cell In[11], line 1
#     print('I will be there at
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('''I will be there at
        9:pm''')
# Out:
# I will be there at
#         9:pm

# %%
print(''''




      hello''')
# Out:
# '
#
#
#
#
#       hello

# %% [markdown]
# ### This Is Called Console Output (ram ki resourse use krna)

# %%
print('Murtaza Ali', end=" ")
print('Data Science & Ai')
# Out:
# Murtaza Ali Data Science & Ai

# %% [markdown]
# #### end fuction work with different lines

# %%
print("AhmedRaza","NasirHussain","MubashirArif", sep="-----")
# Out:
# AhmedRaza-----NasirHussain-----MubashirArif

# %% [markdown]
# ##### seperator works with single line string

# %%
print('My name is murtaza. and i am a student of Ai and Data Science')
# Out:
# My name is murtaza. and i am a student of Ai and Data Science

# %%
print('My name is murtaza.\nI am a student of Ai and Data Science')
# Out:
# My name is murtaza.
# I am a student of Ai and Data Science

# %% [markdown]
# ##### agar line change krni hai eik string ki to mujhay isme \n ka use krna hoga
#         aur koshish krni hogi k \n k baad ma koi extra space na ho

# %% [markdown]
# # Operators (jab 2 cheezon k bech main koi operation perform hota hai isko operators kehty hain
#     common operators
#     = add (+)
#     = subtract (-)
#     = multiply (*)
#     = divide (/) float divition
#     = divide (//) floor divition
#     = modulus (%)
#     = power (**)
# # comparision Operators
#     - greaterthan (>)
#     - less than   (<)
#     - greaterthan and equal to (>=)
#     - equal to (==)
#     - not equal to (!=)
# # Identity opertator
#     - is
# # mebership operator
#     - in
# # logital operators
#     - and
#     - or
#     - not
# # bitwise operator
#     -

# %%
print(23, 45, 'Hello')
# Out:
# 23 45 Hello

# %% [markdown]
# ##### print ko koi msla nhi (int, float, string)

# %%
print(4-2)
# Out:
# 2

# %%
print(4**3)
# Out:
# 64

# %% [markdown]
# ###### power

# %%
# float division
print(12/4)
# Out:
# 3.0

# %%
# floor division
print(12//4)
# Out:
# 3

# %%
# modules hummain remainder deta hia

print(11%4)
# Out:
# 3

# %% [markdown]
# ## comparision operators
#     - kisi bhi tarhan ka comparision krna

# %%
print(12>14)
# Out:
# False

# %%
print(14 > 24)
# Out:
# False

# %%
print(10==10)
# Out:
# True

# %%
print(10!=10)
# Out:
# False

# %%
print(12>=12)
# Out:
# True

# %%
print(12<=8)
# Out:
# False

# %% [markdown]
# ###### comparision operators sirf true or false ma answer deta hai

# %% [markdown]
# # logical operators
#     - jab humaim multiples conditions check karni hoti hain
#     - or operato ko sirf eik condition true milni chahiye to yeh answer true dy deta ha

# %%
12 > 10  or  200<100
# Out:
# True

# %%
12 > 10  or  200<100
# Out:
# True

# %% [raw]
# # or ko sirf eik TRUE chahiye hota hai true hone k liye
# cond 1  or  cond2  result
# True        True   True
# True        False  True
# Flase       True   True
# False       False  False
#
# # AND ko sirf eik False chahiye hota hai False hone k liye
# cond 1  or  cond2  result
# True        True   True
# True        False  False
# Flase       True   False
# False       False  False

# %%
(12 > 10)  and  (200 < 100)
# Out:
# False

# %% [raw]
# har eik value ka boolean hota ha, yani har eik value ka truth he hota hai
# Example:

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(100)
# Out:
# True

# %%
bool("hello")
# Out:
# True

# %%
bool("")
# Out:
# False

# %%
2 and 5
# Out:
# 5

# %%
2 or 5
# Out:
# 2

# %%
x = 100
x = x * 5

# %%
id(x)
# Out:
# 2527663057200

# %%
id(x)
# Out:
# 2527663057200

# %%
x is x = x * 5
# Out:
#   Cell In[9], line 1
#     x is x = x * 5
#     ^
# SyntaxError: cannot assign to comparison

# %% [markdown]
# ##### Bitwise Operators
#         - bits ki level pr ja kr operations perform krta ha

# %%
12 | 5 # or operator sign
# Out:
# 13

# %%
12 & 5  # and operator sign
# Out:
# 4

# %% [markdown]
# # User_input

# %%
age = int(input("enter your age"))
# Out:
# enter your age 23

# %% [markdown]
# # TypeCasting

# %%
float(34.5)
# Out:
# 34.5

# %%
weight = float(input("Entre you weight here"))
# Out:
# Entre you weight here 56.8

# %% [markdown]
# # String concatenation (joining)

# %%
first_name = "Ahemd"
middle_name = "Ali"
last_name = "Akber"

# %%
first_name + middle_name + last_name
# Out:
# 'AhemdAliAkber'

# %%
first_name + age # first_name is string and age is integer
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 first_name + age # first_name is string and age is integer
#
# TypeError: can only concatenate str (not "int") to str
