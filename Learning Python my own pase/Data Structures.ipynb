# %% [markdown]
# # python data strucres: Collection
#  - string
#  - list
#  - dictionary
#  - tuple
#  - set

# %% [markdown]
# ##### Collection
# - when we store more that 1 value in a single variable

# %% [markdown]
# student1 = "Asad"
# student2 = "Rehan"
# student3 = "nasir"
#
# - ahi tak hum log har eik item k lea eik individual varialble bana rahe the jo k sekhay k purpose k lea theek hai lakin long run ma achi practice ni ha,
# - to us surat main hum "list" banaty hain. jo k ziada conviniant hota hai

# %% [markdown]
# # List
# - list ko banay k lea [] square bracket's use hotey hain
# - yeh mutable hoti ha (elements in list can be changed)
# - can holt every valid value
# - Iterable hoti hai: "Loop kar sakte hain"
# -

# %%
#creating an empty list
students = []

# %%
print(type(students))
# Out:
# <class 'list'>

# %%
len(students)
# Out:
# 0

# %%
# creating a membered list:
students = ['Asad', 'Farooq' , 'Shayan' , 'Hashir' , 'Talha' , 'IK' , 'Asim' , 'Aurangzeb']

# %%
len(students)
# Out:
# 8

# %% [markdown]
# #### index: Indices

# %%
#+ve index   0        1         2          3          4         5      6         7           
students = ['Asad', 'Farooq' , 'Shayan' , 'Hashir' , 'Talha' , 'IK' , 'Asim' , 'Aurangzeb']
#-ve index   -8     -7          -6         -5         -4        -3     -2         -1        z

# %% [markdown]
# # Accessing a member using an index number
# - We will use Always use [] to fetch memeber from any collection
# -

# %%
students
# Out:
# ['Asad', 'Farooq', 'Shayan', 'Hashir', 'Talha', 'IK', 'Asim', 'Aurangzeb']

# %% [markdown]
# # List k kisi bhi member ko access karne k lea index number dalna hoga

# %%
students[2]
# Out:
# 'Shayan'

# %%
students[-4]
# Out:
# 'Talha'

# %%
students[4]
# Out:
# 'Talha'

# %% [markdown]
# # hum eik sath multiple member ko sath sath call kar sakte hain

# %%
students[-1] , students[7]
# Out:
# ('Aurangzeb', 'Aurangzeb')

# %% [markdown]
# # Slicing: getting a subset of list
# - yeh asal main humain copy bana kr deta ha

# %%
#+ve index   0        1         2          3          4         5      6         7           
students = ['Asad', 'Farooq' , 'Shayan' , 'Hashir' , 'Talha' , 'IK' , 'Asim' , 'Aurangzeb']
#-ve index   -8     -7          -6         -5         -4        -3     -2         -1        z

# %%
students[1:5] # index 5, willnot be included
# Out:
# ['Farooq', 'Shayan', 'Hashir', 'Talha']

# %% [markdown]
# # kyun k slicing ma akhiri index nhi aata is lea main eik number bhara kr add kar raha hun

# %%
students[4:8]
# Out:
# ['Talha', 'IK', 'Asim', 'Aurangzeb']

# %% [markdown]
# # eik tareeqa yeh bhi ha k hum last wale index ki jaga ko khali chor dain

# %%
students[4:]
# Out:
# ['Talha', 'IK', 'Asim', 'Aurangzeb']

# %% [markdown]
# # indexing hamesha choty sy baray number krni hogi example:

# %%
students[-7:-2]
# Out:
# ['Farooq', 'Shayan', 'Hashir', 'Talha', 'IK']

# %% [markdown]
# # error nhi ata slicing main

# %%
students[-7:7]
# Out:
# ['Farooq', 'Shayan', 'Hashir', 'Talha', 'IK', 'Asim']

# %% [markdown]
# #  aur agar is main hun likhon to slice empyt aye ga kyun hum baray idex sa choty ki taraf nhi bhaj sakte

# %%
#+ve index   0        1         2          3          4         5      6         7           
students = ['Asad', 'Farooq' , 'Shayan' , 'Hashir' , 'Talha' , 'IK' , 'Asim' , 'Aurangzeb']
#-ve index   -8     -7          -6         -5         -4        -3     -2         -1        z

# %%
students[7:2]
# Out:
# []

# %%
students[4:-4]
# Out:
# []

# %% [markdown]
# # example
# - sirf asad print hoga because iski rang he yahan tak hai ,
# - aur last wala index to print he nhi hota
# - bs in cheezon ko yaad rakhain

# %%
students[-8:1]
# Out:
# ['Asad']

# %% [markdown]
# # Distance and Displacement
# - distance change in range
# - displacement change in position

# %%
#+ve index   0        1         2          3          4         5      6         7           
students = ['Asad', 'Farooq' , 'Shayan' , 'Hashir' , 'Talha' , 'IK' , 'Asim' , 'Aurangzeb']
#-ve index   -8     -7          -6         -5         -4        -3     -2         -1        z

# %%
students[0:7:1]  # start , end ,step
# Out:
# ['Asad', 'Farooq', 'Shayan', 'Hashir', 'Talha', 'IK', 'Asim']

# %% [markdown]
# # start, end, step
# - by default step 1 hota
# - step skip kar deta hai

# %%
students[0:7:2]  # start , end ,step
# Out:
# ['Asad', 'Shayan', 'Talha', 'Asim']

# %%
students[0:7:3]  # start , end ,step
# Out:
# ['Asad', 'Hashir', 'Asim']

# %%
#+ve index   0        1         2          3          4         5      6         7           
students = ['Asad', 'Farooq' , 'Shayan' , 'Hashir' , 'Talha' , 'IK' , 'Asim' , 'Aurangzeb']
#-ve index   -8     -7          -6         -5         -4        -3     -2         -1        z

# %% [markdown]
# # List Reverse

# %%
students[::-1] # list ko reverse krdia hai as you can see
# Out:
# ['Aurangzeb', 'Asim', 'IK', 'Talha', 'Hashir', 'Shayan', 'Farooq', 'Asad']

# %%
students[7:4:-1]
# Out:
# ['Aurangzeb', 'Asim', 'IK']

# %%
students [::]
# Out:
# ['Asad', 'Farooq', 'Shayan', 'Hashir', 'Talha', 'IK', 'Asim', 'Aurangzeb']

# %%
students [::1]
# Out:
# ['Asad', 'Farooq', 'Shayan', 'Hashir', 'Talha', 'IK', 'Asim', 'Aurangzeb']

# %%
my_list = [1, 2, 3]
another_list = my_list * 2
print(another_list)
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
list1 = [1, 2, 3]
list2 = list1
list2.append(4)
print(list1)
# Out:
# [1, 2, 3, 4]

# %%
letters = ['a', 'b', 'c', 'd', 'e']
letters[1:4] = ['x', 'y']
print(letters)
# Out:
# ['a', 'x', 'y', 'e']

# %% [markdown]
# # List Functions

# %%
students
# Out:
# ['Asad', 'Farooq', 'Shayan', 'Hashir', 'Talha', 'IK', 'Asim', 'Aurangzeb']

# %% [markdown]
# # adding members in list
# - append() : adds a members in last
# - insert() : adds a member on given index
# - extend() : add another coolection one by one
# - "+"      : Joins two list forms a new list

# %%
students.append('shahbaz')

# %%
students
# Out:
# ['Asad',
#  'Farooq',
#  'Shayan',
#  'Hashir',
#  'Talha',
#  'IK',
#  'Asim',
#  'Aurangzeb',
#  'shahbaz']

# %%
students.insert(4,'Nawaz') # index aur data (sirf eik vaule dal sakete hain)

# %%
students
# Out:
# ['Asad',
#  'Farooq',
#  'Shayan',
#  'Hashir',
#  'Nawaz',
#  'Talha',
#  'IK',
#  'Asim',
#  'Aurangzeb',
#  'shahbaz']

# %%
passed_students = ['ahmed', 'ali', 'faisal' , 'danial' , 'kashif']

# %%
students.append(passed_students)

# %%
students
# Out:
# ['Asad',
#  'Farooq',
#  'Shayan',
#  'Hashir',
#  'Nawaz',
#  'Nawaz',
#  'Nawaz',
#  'Talha',
#  'IK',
#  'Asim',
#  'Aurangzeb',
#  'shahbaz',
#  ['ahmed', 'ali', 'faisal', 'danial', 'kashif']]

# %%
len(students)
# Out:
# 13

# %%
del students[-1]
students
# Out:
# ['Asad',
#  'Farooq',
#  'Shayan',
#  'Hashir',
#  'Nawaz',
#  'Nawaz',
#  'Nawaz',
#  'Talha',
#  'IK',
#  'Asim',
#  'Aurangzeb']

# %%
students.extend(passed_students) # yeh oshe list main extend kr dy ga

# %%
students
# Out:
# ['Asad',
#  'Farooq',
#  'Shayan',
#  'Hashir',
#  'Nawaz',
#  'Nawaz',
#  'Nawaz',
#  'Talha',
#  'IK',
#  'Asim',
#  'Aurangzeb',
#  'ahmed',
#  'ali',
#  'faisal',
#  'danial',
#  'kashif']

# %%
students + [1,2,3,4,5,6,7,8,9] # this makes new list
# Out:
# ['Asad',
#  'Farooq',
#  'Shayan',
#  'Hashir',
#  'Nawaz',
#  'Nawaz',
#  'Nawaz',
#  'Talha',
#  'IK',
#  'Asim',
#  'Aurangzeb',
#  'ahmed',
#  'ali',
#  'faisal',
#  'danial',
#  'kashif',
#  1,
#  2,
#  3,
#  4,
#  5,
#  6,
#  7,
#  8,
#  9]

# %%
students
# Out:
# ['Asad',
#  'Farooq',
#  'Shayan',
#  'Hashir',
#  'Nawaz',
#  'Nawaz',
#  'Nawaz',
#  'Talha',
#  'IK',
#  'Asim',
#  'Aurangzeb',
#  'ahmed',
#  'ali',
#  'faisal',
#  'danial',
#  'kashif']

# %%
passed_students.extend(students)

# %%
passed_students
# Out:
# ['ahmed',
#  'ali',
#  'faisal',
#  'danial',
#  'kashif',
#  'Asad',
#  'Farooq',
#  'Shayan',
#  'Hashir',
#  'Nawaz',
#  'Nawaz',
#  'Nawaz',
#  'Talha',
#  'IK',
#  'Asim',
#  'Aurangzeb',
#  'ahmed',
#  'ali',
#  'faisal',
#  'danial',
#  'kashif',
#  'ahmed',
#  'ali',
#  'faisal',
#  'danial',
#  'kashif']

# %%
students.insert(3,[33,44,55,66])

# %%
students
# Out:
# ['Asad',
#  'Farooq',
#  'Shayan',
#  [33, 44, 55, 66],
#  'Hashir',
#  'Nawaz',
#  'Nawaz',
#  'Nawaz',
#  'Talha',
#  'IK',
#  'Asim',
#  'Aurangzeb',
#  'ahmed',
#  'ali',
#  'faisal',
#  'danial',
#  'kashif',
#  'ahmed',
#  'ali',
#  'faisal',
#  'danial',
#  'kashif']

# %% [markdown]
# # delete a member from list
# - del     : delete by index
# - pop()   : delete by index
# - remove(): delete by value

# %%
del students[3]

# %%
students
# Out:
# ['Asad',
#  'Farooq',
#  'Shayan',
#  'Hashir',
#  'Nawaz',
#  'Nawaz',
#  'Nawaz',
#  'Talha',
#  'IK',
#  'Asim',
#  'Aurangzeb',
#  'ahmed',
#  'ali',
#  'faisal',
#  'danial',
#  'kashif',
#  'ahmed',
#  'ali',
#  'faisal',
#  'danial',
#  'kashif']

# %%
students.remove('Nawaz') # accurance will be remove
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 students.remove('Nawaz') # accurance will be remove
#
# ValueError: list.remove(x): x not in list

# %%
students
# Out:
# ['Asad', 'Farooq', 'Shayan', 'Hashir', 'Talha', 'IK', 'Asim', 'Aurangzeb']

# %%
students
# Out:
# ['Asad',
#  'Farooq',
#  'Shayan',
#  'Hashir',
#  'Talha',
#  'IK',
#  'Asim',
#  'Aurangzeb',
#  'ahmed',
#  'ali',
#  'faisal',
#  'danial',
#  'kashif']

# %%
students.pop(5)
# Out:
# 'IK'

# %% [markdown]
# # students.clear()
# - isko run krte he sari list empty ho jaegi

# %%
del students[:4]

# %%
students
# Out:
# ['Talha', 'Asim', 'Aurangzeb', 'ahmed', 'ali', 'faisal', 'danial', 'kashif']

# %%
passed_students
# Out:
# ['ahmed', 'ali', 'faisal', 'danial', 'kashif']

# %%
students.extend(passed_students)

# %%
students
# Out:
# ['Talha',
#  'Asim',
#  'Aurangzeb',
#  'ahmed',
#  'ali',
#  'faisal',
#  'danial',
#  'kashif',
#  'ahmed',
#  'ali',
#  'faisal',
#  'danial',
#  'kashif']
