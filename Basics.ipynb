# %%
#print("fiza")

var1 = "fiza"
var2 = "baneen"
var3 = var1+var2
var4 = var1
#

# %%
id(var1)
# Out:
# 2058774801520

# %%
id(var4)
# Out:
# 2058774801520

# %% [markdown]
# # Common DataTypes
#     - integer
